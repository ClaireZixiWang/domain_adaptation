# %%
import torch, os
import torch.nn as nn
import torchvision.datasets as datasets
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
import random
import torch.utils.data as torchdata
from torch.utils.data import SubsetRandomSampler
import matplotlib.pyplot as plt
# from train_model import train_model
# from test_model import test_model
# %matplotlib inline
import time

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]='2'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
filePath = '/local/rcs/ll3504/datasets/256_ObjectCategories/'
namelist = os.listdir(filePath)
nameDic_cal = {}
for name in namelist:
    splits = name.split(".")
    nameDic_cal[int(splits[0])-1] = splits[1]
print(nameDic_cal[1])
# Out:
# american-flag

# %%
def get_dataset(path='/database', dataset_name='caltech-256-common'):
    # No holdout testing data. train and test data are the same, but different transformation
    data_transforms = {
        'train': transforms.Compose([
#             transforms.Resize([256, 256]),
#             transforms.RandomCrop(224),
#             transforms.RandomRotation(20),
#             transforms.RandomHorizontalFlip(0.5),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ]),
        'test': transforms.Compose([
#             transforms.Resize([224, 224]),
#             transforms.CenterCrop((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
    }

    tr_dataset = datasets.ImageFolder(path + dataset_name + '/', data_transforms['train'])
    te_dataset = datasets.ImageFolder(path + dataset_name + '/', data_transforms['test'])
#     print('{} train set size: {}'.format(dataset_name, len(tr_dataset)))
#     print('{} test set size: {}'.format(dataset_name, len(te_dataset)))

    return tr_dataset, te_dataset

# %%
def split_dataset(train_dataset, test_dataset, valid_size=0.2, batch_size=128, train_size = 128):
    '''
    This function splits dataset into train, val, and test sets, and return train, val, test dataloaders.
    Val and Test loaders are the same

    '''
    
    # what does the len function gives?
    num_train = len(train_dataset)
    # print("DEBUGGING: overall training data size =", num_train)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    random.shuffle(indices)
    train_idx, valid_idx = indices[split:split+train_size], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)
    
    # print("DEBUGGING: the train_ind are:", len(train_idx))


    train_loader = torchdata.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=48, pin_memory=True, drop_last=True, sampler = train_sampler)
    test_loader = torchdata.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=48, pin_memory=True, drop_last=True, sampler = valid_sampler)
    dataloaders = {'train': train_loader,
                   'val': test_loader,
                   'test': test_loader}
    dataset_sizes ={'train': train_size, #int(np.floor((1-valid_size) * num_train)),
                    'val': int(np.floor(valid_size * num_train)),
                    'test': int(np.floor(valid_size * num_train))}
    return dataloaders, dataset_sizes

# %%
imagebase = '/local/rcs/ll3504/datasets/'

# %%
corruption = ['zoom_blur', 'speckle_noise', 'spatter',
                       'snow', 'glass_blur', 'motion_blur', 'saturate',
                       'gaussian_blur', 'frost', 'fog', 'brightness', 'contrast',
                       'elastic_transform', 'pixelate', 'jpeg_compression', 'defocus_blur']

# %% [markdown]
# # ImageNetC

# %%
def get_imagenetc(imagebase, severity=1, batch_size=128, sample_size = 128):
    '''
    Returns:
        ref_dataloaders:          ImageNet original validation data, as a reference
        ref_dataset_sizes:        1000, not the sizes of the real dataset in the ref_loader, probs used downstream
        corrupted_dataloaders:    A list of corrupted dataloaders, each element in a list represetns the data loaders
                                  for one corruption type. Each element contains ['train']['val']['test'] loaders
        corrupted_dataset_sizes:  A list of dictionaries of the sizes of each loaders for each corruption
        corruption:               A list of corruption names, in the same order of the corrupted_dataloaders
    '''
    corruption = ['zoom_blur', 'speckle_noise', 'spatter',
                       'snow', 'glass_blur', 'motion_blur', 'saturate',
                       'gaussian_blur', 'frost', 'fog', 'brightness', 'contrast',
                       'elastic_transform', 'pixelate', 'jpeg_compression', 'defocus_blur']
    corrupted_dataloaders = []
    corrupted_dataset_sizes = []
    
    # this is the imageNet validation data
    imagenet_val = datasets.ImageNet(imagebase+'imagenetc/', split='val', transform=transforms.Compose([
            transforms.Resize([224, 224]),
            transforms.CenterCrop((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ]),
                                   target_transform=None)#, download=False)
    
    # TODO: subsample some size of ImageNet training data as source
        # Doesn't need this step
#     print("DEBUGGING: imagenet_val size is:", len(imagenet_val))
    
    random_indices = random.sample(range(0, len(imagenet_val)), int(len(imagenet_val)*0.02))
#     print("DEBUGGING: random indices are:", len(random_indices))
    imagenet_val_subset = data.Subset(imagenet_val, random_indices)
    val_loader = torch.utils.data.DataLoader(imagenet_val_subset,
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=48)
    ref_dataloaders = { 'val': val_loader,
                       'test': val_loader}
    ref_dataset_sizes ={'val': int(len(val_loader.dataset)),
                        'test': int(len(val_loader.dataset))}
    
    # for every type of corruption, go to the specified severity folder
    for corr in corruption:
        dataset_name = 'imagenetc/' + corr + '/' + str(severity)
        # Get dataset from folder
        corr_trian_images, corr_test_images = get_dataset(imagebase, dataset_name)
        # get corruption-specific train, val, test loader
        # train: training data, non-overlap with val/test
        # val: non-overlap with train, same as test
        # test: non-overlap with train, same as test
        corr_dataloaders, corr_dataset_sizes = split_dataset(corr_trian_images, corr_test_images, valid_size=0.02, batch_size=batch_size, train_size=sample_size)
        corrupted_dataloaders.append(corr_dataloaders)
        corrupted_dataset_sizes.append(corr_dataset_sizes)
    return ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption

# %%
ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
= get_imagenetc(imagebase, 5, 32, 32)
# training size = 50000 - 1000 = 49000

# %%
# in total 16 corruptions, each have 3 dataloaders ['train']['val']['test']
len(corrupted_dataloaders[15]['val']) # why is this 31??
# Out:
# 31

# %%
corrupted_dataset_sizes[0]
# Out:
# {'train': 32, 'val': 1000, 'test': 1000}

# %%
ref_dataset_sizes['val']
# Out:
# 1000

# %%
len(ref_dataloaders['val'])
# Out:
# 32

# %% [markdown]
# # RPL - Original Code experiments

# %%
import torch
from torchvision import models, datasets, transforms

def get_dataset_loader(valdir, batch_size, shuffle):
    val_dataset = datasets.ImageFolder(valdir, transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        ),
    ]))
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=shuffle
    )
    return val_loader

def gce(logits, target, q = 0.8):
    """ Generalized cross entropy.
    
    Reference: https://arxiv.org/abs/1805.07836
    """
    probs = torch.nn.functional.softmax(logits, dim=1)
    probs_with_correct_idx = probs.index_select(-1, target).diag()
    loss = (1. - probs_with_correct_idx**q) / q
    return loss.mean()

def adapt_batchnorm(model):
    model.eval()
    parameters = []
    for module in model.modules():
        if isinstance(module, torch.nn.BatchNorm2d):
            parameters.extend(module.parameters())
            module.train()
    return parameters


# ---

def evaluate(
        data_loader,
        datadir = '/data/imagenetc/gaussian_blur/3',
        num_epochs = 5, # orig = 5
        batch_size = 96, # orig = 96
        learning_rate = 0.75e-3,
        gce_q = 0.8
    ):

    baseline = models.resnet50(pretrained = True).to(device)
    baseline.eval()
    
    model = models.resnet50(pretrained = True).to(device)
    parameters = adapt_batchnorm(model)
#     val_loader = get_dataset_loader(
#         datadir,
#         batch_size = batch_size,
#         shuffle = True
#     )
    optimizer = torch.optim.SGD(
        parameters, lr = learning_rate  # orig = model.parameters()
    )
    
    b_correct, num_correct, num_samples = 0., 0., 0.
    
    base_acc = []
    base_acc_epoch = []
    adapted_train_acc_overall = []
    adapted_train_acc_per_epoch = []
    adapted_train_acc_per_iter = []
    
    training_time = []
    
    start = time.time()
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}')
        b_correct_epoch, num_correct_epoch, num_samples_epoch = 0., 0., 0.

        for images, targets in data_loader:

            logits = model(images.to(device))
            predictions = logits.argmax(dim = 1)
            loss = gce(logits, predictions, q = gce_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            num_correct += (predictions.detach().cpu() == targets).float().sum()
            num_samples += len(targets)
            
            num_correct_epoch += (predictions.detach().cpu() == targets).float().sum()
            num_samples_epoch += len(targets)
            
            b_logits = baseline(images.to(device))
            b_predictions = b_logits.argmax(dim = 1)
            b_correct += (b_predictions.detach().cpu() == targets).float().sum()
            b_correct_epoch += (b_predictions.detach().cpu() == targets).float().sum()
            
            adapted_train_acc_per_iter.append((predictions.detach().cpu()==targets).float().sum()/len(targets))
        
        epoch_time = time.time() - start
        training_time.append(epoch_time)
        
        base_acc.append(b_correct / num_samples)
        adapted_train_acc_overall.append(num_correct / num_samples)
        
        base_acc_epoch.append(b_correct_epoch / num_samples_epoch)
        adapted_train_acc_per_epoch.append(num_correct_epoch / num_samples_epoch)

        print(f"Baseline Correct: {b_correct:#5.0f}/{num_samples:#5.0f} ({100 * b_correct / num_samples:.2f} %)")
        print(f"Adapted Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
        print(f"Baseline Epoch Correct: {b_correct_epoch:#5.0f}/{num_samples_epoch:#5.0f} ({100 * b_correct_epoch / num_samples_epoch:.2f} %)")
        print(f"Adapted Epoch Correct: {num_correct_epoch:#5.0f}/{num_samples_epoch:#5.0f} ({100 * num_correct_epoch / num_samples_epoch:.2f} %)")
        
        
    return base_acc, base_acc_epoch, adapted_train_acc_overall, adapted_train_acc_per_epoch, adapted_train_acc_per_iter, model, baseline, training_time

# %% [markdown]
# ## Abalation studies

# %% [markdown]
# ### 1. Epochs

# %%
record_epochs = {}
batch_size = 32
sample_size = 32

print("Running experiment for batch_size =", batch_size)

ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
= get_imagenetc(imagebase, 3, batch_size, sample_size)

base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, model, baseline, training_time = evaluate(corrupted_dataloaders[0]['train'], num_epochs=500)

record_epochs[batch_size] = base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, training_time
# Out:
# Running experiment for batch_size = 32
# Epoch 0
# Baseline Correct:    7./  32. (21.88 %)
# Adapted Correct:   10./  32. (31.25 %)
# Baseline Epoch Correct:    7./  32. (21.88 %)
# Adapted Epoch Correct:   10./  32. (31.25 %)
# Epoch 1
# Baseline Correct:   10./  64. (15.62 %)
# Adapted Correct:   16./  64. (25.00 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 2
# Baseline Correct:   17./  96. (17.71 %)
# Adapted Correct:   22./  96. (22.92 %)
# Baseline Epoch Correct:    7./  32. (21.88 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 3
# Baseline Correct:   21./ 128. (16.41 %)
# Adapted Correct:   29./ 128. (22.66 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 4
# Baseline Correct:   25./ 160. (15.62 %)
# Adapted Correct:   34./ 160. (21.25 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 5
# Baseline Correct:   30./ 192. (15.62 %)
# Adapted Correct:   40./ 192. (20.83 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 6
# Baseline Correct:   36./ 224. (16.07 %)
# Adapted Correct:   46./ 224. (20.54 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 7
# Baseline Correct:   39./ 256. (15.23 %)
# Adapted Correct:   50./ 256. (19.53 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    4./  32. (12.50 %)
# Epoch 8
# Baseline Correct:   44./ 288. (15.28 %)
# Adapted Correct:   55./ 288. (19.10 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 9
# Baseline Correct:   50./ 320. (15.62 %)
# Adapted Correct:   63./ 320. (19.69 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    8./  32. (25.00 %)
# Epoch 10
# Baseline Correct:   55./ 352. (15.62 %)
# Adapted Correct:   68./ 352. (19.32 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 11
# Baseline Correct:   59./ 384. (15.36 %)
# Adapted Correct:   75./ 384. (19.53 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 12
# Baseline Correct:   64./ 416. (15.38 %)
# Adapted Correct:   81./ 416. (19.47 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 13
# Baseline Correct:   71./ 448. (15.85 %)
# Adapted Correct:   88./ 448. (19.64 %)
# Baseline Epoch Correct:    7./  32. (21.88 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 14
# Baseline Correct:   77./ 480. (16.04 %)
# Adapted Correct:   94./ 480. (19.58 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 15
# Baseline Correct:   82./ 512. (16.02 %)
# Adapted Correct:   98./ 512. (19.14 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    4./  32. (12.50 %)
# Epoch 16
# Baseline Correct:   85./ 544. (15.62 %)
# Adapted Correct:  104./ 544. (19.12 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 17
# Baseline Correct:   90./ 576. (15.62 %)
# Adapted Correct:  109./ 576. (18.92 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 18
# Baseline Correct:   95./ 608. (15.62 %)
# Adapted Correct:  114./ 608. (18.75 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 19
# Baseline Correct:  100./ 640. (15.62 %)
# Adapted Correct:  121./ 640. (18.91 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 20
# Baseline Correct:  105./ 672. (15.62 %)
# Adapted Correct:  127./ 672. (18.90 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 21
# Baseline Correct:  108./ 704. (15.34 %)
# Adapted Correct:  134./ 704. (19.03 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 22
# Baseline Correct:  111./ 736. (15.08 %)
# Adapted Correct:  139./ 736. (18.89 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 23
# Baseline Correct:  115./ 768. (14.97 %)
# Adapted Correct:  144./ 768. (18.75 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 24
# Baseline Correct:  123./ 800. (15.38 %)
# Adapted Correct:  152./ 800. (19.00 %)
# Baseline Epoch Correct:    8./  32. (25.00 %)
# Adapted Epoch Correct:    8./  32. (25.00 %)
# Epoch 25
# Baseline Correct:  129./ 832. (15.50 %)
# Adapted Correct:  157./ 832. (18.87 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 26
# Baseline Correct:  135./ 864. (15.62 %)
# Adapted Correct:  164./ 864. (18.98 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 27
# Baseline Correct:  141./ 896. (15.74 %)
# Adapted Correct:  170./ 896. (18.97 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 28
# Baseline Correct:  145./ 928. (15.62 %)
# Adapted Correct:  176./ 928. (18.97 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 29
# Baseline Correct:  150./ 960. (15.62 %)
# Adapted Correct:  183./ 960. (19.06 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 30
# Baseline Correct:  155./ 992. (15.62 %)
# Adapted Correct:  190./ 992. (19.15 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 31
# Baseline Correct:  158./1024. (15.43 %)
# Adapted Correct:  195./1024. (19.04 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 32
# Baseline Correct:  162./1056. (15.34 %)
# Adapted Correct:  200./1056. (18.94 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 33
# Baseline Correct:  166./1088. (15.26 %)
# Adapted Correct:  207./1088. (19.03 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 34
# Baseline Correct:  173./1120. (15.45 %)
# Adapted Correct:  213./1120. (19.02 %)
# Baseline Epoch Correct:    7./  32. (21.88 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 35
# Baseline Correct:  177./1152. (15.36 %)
# Adapted Correct:  221./1152. (19.18 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    8./  32. (25.00 %)
# Epoch 36
# Baseline Correct:  180./1184. (15.20 %)
# Adapted Correct:  228./1184. (19.26 %)
# Baseline Epoch Correct:    3./  32. (9.38 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 37
# Baseline Correct:  185./1216. (15.21 %)
# Adapted Correct:  233./1216. (19.16 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    5./  32. (15.62 %)
# Epoch 38
# Baseline Correct:  190./1248. (15.22 %)
# Adapted Correct:  239./1248. (19.15 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 39
# Baseline Correct:  195./1280. (15.23 %)
# Adapted Correct:  246./1280. (19.22 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 40
# Baseline Correct:  202./1312. (15.40 %)
# Adapted Correct:  252./1312. (19.21 %)
# Baseline Epoch Correct:    7./  32. (21.88 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 41
# Baseline Correct:  206./1344. (15.33 %)
# Adapted Correct:  260./1344. (19.35 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    8./  32. (25.00 %)
# Epoch 42
# Baseline Correct:  210./1376. (15.26 %)
# Adapted Correct:  267./1376. (19.40 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    7./  32. (21.88 %)
# Epoch 43
# Baseline Correct:  216./1408. (15.34 %)
# Adapted Correct:  273./1408. (19.39 %)
# Baseline Epoch Correct:    6./  32. (18.75 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 44
# Baseline Correct:  218./1440. (15.14 %)
# Adapted Correct:  279./1440. (19.38 %)
# Baseline Epoch Correct:    2./  32. (6.25 %)
# Adapted Epoch Correct:    6./  32. (18.75 %)
# Epoch 45
# Baseline Correct:  223./1472. (15.15 %)
# Adapted Correct:  284./1472. (19.29 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:
%)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:   10./  32. (31.25 %)
# Epoch 495
# Baseline Correct: 2342./15872. (14.76 %)
# Adapted Correct: 4181./15872. (26.34 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:    9./  32. (28.12 %)
# Epoch 496
# Baseline Correct: 2346./15904. (14.75 %)
# Adapted Correct: 4196./15904. (26.38 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:   15./  32. (46.88 %)
# Epoch 497
# Baseline Correct: 2350./15936. (14.75 %)
# Adapted Correct: 4208./15936. (26.41 %)
# Baseline Epoch Correct:    4./  32. (12.50 %)
# Adapted Epoch Correct:   12./  32. (37.50 %)
# Epoch 498
# Baseline Correct: 2355./15968. (14.75 %)
# Adapted Correct: 4217./15968. (26.41 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    9./  32. (28.12 %)
# Epoch 499
# Baseline Correct: 2360./16000. (14.75 %)
# Adapted Correct: 4225./16000. (26.41 %)
# Baseline Epoch Correct:    5./  32. (15.62 %)
# Adapted Epoch Correct:    8./  32. (25.00 %)

# %%
len(base_acc)
# Out:
# 500

# %%
# Acc on the validation dataset
model.eval()
baseline.eval()
val_loader = corrupted_dataloaders[0]['val']
b_correct, num_correct, num_samples = 0., 0., 0.

for images, targets in val_loader:

    logits = model(images.to(device))
    predictions = logits.argmax(dim = 1)

    num_correct += (predictions.detach().cpu() == targets).float().sum()
    num_samples += len(targets)

    b_logits = baseline(images.to(device))
    b_predictions = b_logits.argmax(dim = 1)
    b_correct += (b_predictions.detach().cpu() == targets).float().sum()

    base_val_acc = (b_correct/num_samples)
    adapted_val_acc = (num_correct/num_samples)

print(f"Baseline Val Acc: {b_correct:#5.0f}/{num_samples:#5.0f} ({100 * b_correct / num_samples:.2f} %)")
print(f"Adapted Val Acc: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
# Out:
# Baseline Val Acc:  355./ 992. (35.79 %)
# Adapted Val Acc:  421./ 992. (42.44 %)

# %%
# Training accuracy over iterations
# TODO: set x-axis, set plot size

plt.plot(base_acc, label='baseline acc')
# plt.plot(base_acc_epoch, label='baseline acc epoch')
plt.plot(adapted_online_acc_overall, label='adapted acc overall')
plt.plot(adapted_train_acc_per_epoch, label='adapted acc per epoch')
# plt.plot(training_time)
# plt.plot(adapted_online_acc_per_iter, label='adapted acc per iter')
plt.legend()
plt.title('Training accuracies over iterations, batch_size = ' + str(batch_size))

plt.show()

# %%
plt.plot(training_time)

# %% [markdown]
# Extreme overfitting, might be useful when doing some online adaptation? (really?)
#
# Haven't test its applicability to val set, I persume will NOT be good.

# %%
## TODO: Saving the recorded performances
## 
import pickle

with open('acc_record_epochs.pkl', 'wb') as f:
    pickle.dump(acc_record_epochs, f)
        
with open('acc_record_epochs.pkl', 'rb') as f:
    acc_record_epochs = pickle.load(f)

# %% [markdown]
# ### 2. Sample_size

# %%
acc_record_samplesize = {} #acc_record_samplesize[ss] = [base_acc], [base_acc_epoch], [adapted_online_acc_overall], [adapted_train_acc_per_epoch], [adapted_online_acc_per_batch], base_val_acc, adapted_val_acc, [training_time]
batch_size = 32
sample_sizes = [32, 64, 96, 128, 256, 512, 1028]

for ss in sample_sizes:

    print("Running experiment for sample_size =", ss)

    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, 3, batch_size, ss)

    base_acc, base_acc_epoch, adapted_train_acc_overall, adapted_train_acc_per_epoch, adapted_train_acc_per_iter, \
    model, baseline, training_time = evaluate(corrupted_dataloaders[0]['train'], num_epochs=50)
    
    ## evaluate on val set
    model.eval()
    baseline.eval()
    with torch.no_grad():
        base_val_correct, crpt_val_correct, crpt_val_samples = 0, 0, 0
        for images, labels in corrupted_dataloaders[0]['val']:
            labels = labels.to(device)
            outputs = model(images.to(device))
            _, predicted = torch.max(outputs.data, 1)
            crpt_val_correct += (predicted == labels).sum().item()
            crpt_val_samples += len(labels)

            b_outputs = baseline(images.to(device))
            _, b_predicted = torch.max(b_outputs.data, 1)
            base_val_correct += (b_predicted == labels).sum().item()


    print(f"Corrupt Val Adapt Accuracy: {crpt_val_correct:#5.0f}/{crpt_val_samples:#5.0f} ({crpt_val_correct / crpt_val_samples})")
    print(f"Corrupt Val Base Accuracy: {base_val_correct:#5.0f}/{crpt_val_samples:#5.0f} ({base_val_correct / crpt_val_samples})")

    acc_record_samplesize[ss] = [base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, (base_val_correct/crpt_val_samples), (crpt_val_correct/crpt_val_samples), training_time]
    
    print("===================================================================================================")
# Out:
# Running experiment for sample_size = 32
# Epoch 0
# Baseline Correct:   15./  32. (46.88 %)
# Adapted Correct:   22./  32. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 1
# Baseline Correct:   30./  64. (46.88 %)
# Adapted Correct:   44./  64. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 2
# Baseline Correct:   45./  96. (46.88 %)
# Adapted Correct:   66./  96. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 3
# Baseline Correct:   60./ 128. (46.88 %)
# Adapted Correct:   88./ 128. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 4
# Baseline Correct:   75./ 160. (46.88 %)
# Adapted Correct:  110./ 160. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 5
# Baseline Correct:   90./ 192. (46.88 %)
# Adapted Correct:  132./ 192. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 6
# Baseline Correct:  105./ 224. (46.88 %)
# Adapted Correct:  154./ 224. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 7
# Baseline Correct:  120./ 256. (46.88 %)
# Adapted Correct:  176./ 256. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 8
# Baseline Correct:  135./ 288. (46.88 %)
# Adapted Correct:  198./ 288. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 9
# Baseline Correct:  150./ 320. (46.88 %)
# Adapted Correct:  220./ 320. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 10
# Baseline Correct:  165./ 352. (46.88 %)
# Adapted Correct:  242./ 352. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 11
# Baseline Correct:  180./ 384. (46.88 %)
# Adapted Correct:  264./ 384. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 12
# Baseline Correct:  195./ 416. (46.88 %)
# Adapted Correct:  286./ 416. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 13
# Baseline Correct:  210./ 448. (46.88 %)
# Adapted Correct:  308./ 448. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 14
# Baseline Correct:  225./ 480. (46.88 %)
# Adapted Correct:  330./ 480. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 15
# Baseline Correct:  240./ 512. (46.88 %)
# Adapted Correct:  352./ 512. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 16
# Baseline Correct:  255./ 544. (46.88 %)
# Adapted Correct:  374./ 544. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 17
# Baseline Correct:  270./ 576. (46.88 %)
# Adapted Correct:  396./ 576. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 18
# Baseline Correct:  285./ 608. (46.88 %)
# Adapted Correct:  418./ 608. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 19
# Baseline Correct:  300./ 640. (46.88 %)
# Adapted Correct:  440./ 640. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 20
# Baseline Correct:  315./ 672. (46.88 %)
# Adapted Correct:  462./ 672. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 21
# Baseline Correct:  330./ 704. (46.88 %)
# Adapted Correct:  484./ 704. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 22
# Baseline Correct:  345./ 736. (46.88 %)
# Adapted Correct:  506./ 736. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 23
# Exception ignored in: <function _ConnectionBase.__del__ at 0x7f50b042c280>
# Traceback (most recent call last):
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 137, in __del__
# Traceback (most recent call last):
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/queues.py", line 241, in _feed
#     close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/queues.py", line 241, in _feed
#     close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/queues.py", line 241, in _feed
#     close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Traceback (most recent call last):
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/queues.py", line 241, in _feed
#     close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#     self._close()
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Baseline Correct:  360./ 768. (46.88 %)
# Adapted Correct:  528./ 768. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 24
# Baseline Correct:  375./ 800. (46.88 %)
# Adapted Correct:  550./ 800. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 25
# Baseline Correct:  390./ 832. (46.88 %)
# Adapted Correct:  572./ 832. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 26
# Baseline Correct:  405./ 864. (46.88 %)
# Adapted Correct:  594./ 864. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 27
# Baseline Correct:  420./ 896. (46.88 %)
# Adapted Correct:  616./ 896. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 28
# Baseline Correct:  435./ 928. (46.88 %)
# Adapted Correct:  638./ 928. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 29
# Baseline Correct:  450./ 960. (46.88 %)
# Adapted Correct:  660./ 960. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 30
# Baseline Correct:  465./ 992. (46.88 %)
# Adapted Correct:  682./ 992. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 31
# Baseline Correct:  480./1024. (46.88 %)
# Adapted Correct:  704./1024. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 32
# Baseline Correct:  495./1056. (46.88 %)
# Adapted Correct:  726./1056. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 33
# Baseline Correct:  510./1088. (46.88 %)
# Adapted Correct:  748./1088. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 34
# Baseline Correct:  525./1120. (46.88 %)
# Adapted Correct:  770./1120. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 35
# Baseline Correct:  540./1152. (46.88 %)
# Adapted Correct:  792./1152. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 36
# Baseline Correct:  555./1184. (46.88 %)
# Adapted Correct:  814./1184. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 37
# Baseline Correct:  570./1216. (46.88 %)
# Adapted Correct:  836./1216. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 38
# Baseline Correct:  585./1248. (46.88 %)
# Adapted Correct:  858./1248. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 39
# Baseline Correct:  600./1280. (46.88 %)
# Adapted Correct:  880./1280. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 40
# Baseline Correct:  615./1312. (46.88 %)
# Adapted Correct:  902./1312. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 41
# Baseline Correct:  630./1344. (46.88 %)
# Adapted Correct:  924./1344. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 42
# Baseline Correct:  645./1376. (46.88 %)
# Adapted Correct:  946./1376. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 43
# Baseline Correct:  660./1408. (46.88 %)
# Adapted Correct:  968./1408. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 44
# Baseline Correct:  675./1440. (46.88 %)
# Adapted Correct:  990./1440. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 45
# Baseline Correct:  690./1472. (46.88 %)
# Adapted Correct: 1012./1472. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 46
# Baseline Correct:  705./1504. (46.88 %)
# Adapted Correct: 1034./1504. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 47
# Baseline Correct:  720./1536. (46.88 %)
# Adapted Correct: 1056./1536. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 48
# Baseline Correct:  735./1568. (46.88 %)
# Adapted Correct: 1078./1568. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Epoch 49
# Baseline Correct:  750./1600. (46.88 %)
# Adapted Correct: 1100./1600. (68.75 %)
# Baseline Epoch Correct:   15./  32. (46.88 %)
# Adapted Epoch Correct:   22./  32. (68.75 %)
# Corrupt Val Adapt Accuracy:  494./ 992. (0.49798387096774194)
# Corrupt Val Base Accuracy:  320./ 992. (0.3225806451612903)
# ===================================================================================================
# Running experiment for sample_size = 64
# Epoch 0
# Baseline Correct:   26./  64. (40.62 %)
# Adapted Correct:   33./  64. (51.56 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   33./  64. (51.56 %)
# Epoch 1
# Baseline Correct:   52./ 128. (40.62 %)
# Adapted Correct:   64./ 128. (50.00 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   31./  64. (48.44 %)
# Epoch 2
# Baseline Correct:   78./ 192. (40.62 %)
# Adapted Correct:   95./ 192. (49.48 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   31./  64. (48.44 %)
# Epoch 3
# Baseline Correct:  104./ 256. (40.62 %)
# Adapted Correct:  126./ 256. (49.22 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   31./  64. (48.44 %)
# Epoch 4
# Baseline Correct:  130./ 320. (40.62 %)
# Adapted Correct:  158./ 320. (49.38 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   32./  64. (50.00 %)
# Epoch 5
# Baseline Correct:  156./ 384. (40.62 %)
# Adapted Correct:  193./ 384. (50.26 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 6
# Baseline Correct:  182./ 448. (40.62 %)
# Adapted Correct:  228./ 448. (50.89 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 7
# Baseline Correct:  208./ 512. (40.62 %)
# Adapted Correct:  264./ 512. (51.56 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   36./  64. (56.25 %)
# Epoch 8
# Baseline Correct:  234./ 576. (40.62 %)
# Adapted Correct:  298./ 576. (51.74 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 9
# Baseline Correct:  260./ 640. (40.62 %)
# Adapted Correct:  332./ 640. (51.88 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 10
# Baseline Correct:  286./ 704. (40.62 %)
# Adapted Correct:  364./ 704. (51.70 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   32./  64. (50.00 %)
# Epoch 11
# Baseline Correct:  312./ 768. (40.62 %)
# Adapted Correct:  395./ 768. (51.43 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   31./  64. (48.44 %)
# Epoch 12
# Baseline Correct:  338./ 832. (40.62 %)
# Adapted Correct:  429./ 832. (51.56 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 13
# Baseline Correct:  364./ 896. (40.62 %)
# Adapted Correct:  463./ 896. (51.67 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 14
# Baseline Correct:  390./ 960. (40.62 %)
# Adapted Correct:  497./ 960. (51.77 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 15
# Baseline Correct:  416./1024. (40.62 %)
# Adapted Correct:  532./1024. (51.95 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 16
# Baseline Correct:  442./1088. (40.62 %)
# Adapted Correct:  565./1088. (51.93 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   33./  64. (51.56 %)
# Epoch 17
# Baseline Correct:  468./1152. (40.62 %)
# Adapted Correct:  598./1152. (51.91 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   33./  64. (51.56 %)
# Epoch 18
# Baseline Correct:  494./1216. (40.62 %)
# Adapted Correct:  633./1216. (52.06 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 19
# Baseline Correct:  520./1280. (40.62 %)
# Adapted Correct:  666./1280. (52.03 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   33./  64. (51.56 %)
# Epoch 20
# Baseline Correct:  546./1344. (40.62 %)
# Adapted Correct:  700./1344. (52.08 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 21
# Baseline Correct:  572./1408. (40.62 %)
# Adapted Correct:  736./1408. (52.27 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   36./  64. (56.25 %)
# Epoch 22
# Baseline Correct:  598./1472. (40.62 %)
# Adapted Correct:  768./1472. (52.17 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   32./  64. (50.00 %)
# Epoch 23
# Baseline Correct:  624./1536. (40.62 %)
# Adapted Correct:  800./1536. (52.08 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   32./  64. (50.00 %)
# Epoch 24
# Baseline Correct:  650./1600. (40.62 %)
# Adapted Correct:  834./1600. (52.12 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   34./  64. (53.12 %)
# Epoch 25
# Baseline Correct:  676./1664. (40.62 %)
# Adapted Correct:  869./1664. (52.22 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 26
# Baseline Correct:  702./1728. (40.62 %)
# Adapted Correct:  901./1728. (52.14 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   32./  64. (50.00 %)
# Epoch 27
# Baseline Correct:  728./1792. (40.62 %)
# Adapted Correct:  936./1792. (52.23 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:   35./  64. (54.69 %)
# Epoch 28
# Baseline Correct:  754./1856. (40.62 %)
# Adapted Correct:  971./1856. (52.32 %)
# Baseline Epoch Correct:   26./  64. (40.62 %)
# Adapted Epoch Correct:
%)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   51./  96. (53.12 %)
# Epoch 1
# Baseline Correct:   68./ 192. (35.42 %)
# Adapted Correct:  104./ 192. (54.17 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 2
# Baseline Correct:  102./ 288. (35.42 %)
# Adapted Correct:  158./ 288. (54.86 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   54./  96. (56.25 %)
# Epoch 3
# Baseline Correct:  136./ 384. (35.42 %)
# Adapted Correct:  211./ 384. (54.95 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 4
# Baseline Correct:  170./ 480. (35.42 %)
# Adapted Correct:  264./ 480. (55.00 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 5
# Baseline Correct:  204./ 576. (35.42 %)
# Adapted Correct:  315./ 576. (54.69 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   51./  96. (53.12 %)
# Epoch 6
# Baseline Correct:  238./ 672. (35.42 %)
# Adapted Correct:  364./ 672. (54.17 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   49./  96. (51.04 %)
# Epoch 7
# Baseline Correct:  272./ 768. (35.42 %)
# Adapted Correct:  416./ 768. (54.17 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Epoch 8
# Baseline Correct:  306./ 864. (35.42 %)
# Adapted Correct:  467./ 864. (54.05 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   51./  96. (53.12 %)
# Epoch 9
# Baseline Correct:  340./ 960. (35.42 %)
# Adapted Correct:  521./ 960. (54.27 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   54./  96. (56.25 %)
# Epoch 10
# Baseline Correct:  374./1056. (35.42 %)
# Adapted Correct:  576./1056. (54.55 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   55./  96. (57.29 %)
# Epoch 11
# Baseline Correct:  408./1152. (35.42 %)
# Adapted Correct:  629./1152. (54.60 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 12
# Baseline Correct:  442./1248. (35.42 %)
# Adapted Correct:  682./1248. (54.65 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 13
# Baseline Correct:  476./1344. (35.42 %)
# Adapted Correct:  734./1344. (54.61 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Epoch 14
# Baseline Correct:  510./1440. (35.42 %)
# Adapted Correct:  787./1440. (54.65 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 15
# Baseline Correct:  544./1536. (35.42 %)
# Adapted Correct:  841./1536. (54.75 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   54./  96. (56.25 %)
# Epoch 16
# Baseline Correct:  578./1632. (35.42 %)
# Adapted Correct:  895./1632. (54.84 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   54./  96. (56.25 %)
# Epoch 17
# Baseline Correct:  612./1728. (35.42 %)
# Adapted Correct:  950./1728. (54.98 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   55./  96. (57.29 %)
# Epoch 18
# Baseline Correct:  646./1824. (35.42 %)
# Adapted Correct: 1003./1824. (54.99 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 19
# Baseline Correct:  680./1920. (35.42 %)
# Adapted Correct: 1055./1920. (54.95 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Epoch 20
# Baseline Correct:  714./2016. (35.42 %)
# Adapted Correct: 1109./2016. (55.01 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   54./  96. (56.25 %)
# Epoch 21
# Baseline Correct:  748./2112. (35.42 %)
# Adapted Correct: 1160./2112. (54.92 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:
%)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 45
# Baseline Correct: 1564./4416. (35.42 %)
# Adapted Correct: 2440./4416. (55.25 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   56./  96. (58.33 %)
# Epoch 46
# Baseline Correct: 1598./4512. (35.42 %)
# Adapted Correct: 2493./4512. (55.25 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   53./  96. (55.21 %)
# Epoch 47
# Baseline Correct: 1632./4608. (35.42 %)
# Adapted Correct: 2545./4608. (55.23 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Epoch 48
# Baseline Correct: 1666./4704. (35.42 %)
# Adapted Correct: 2597./4704. (55.21 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Epoch 49
# Baseline Correct: 1700./4800. (35.42 %)
# Adapted Correct: 2649./4800. (55.19 %)
# Baseline Epoch Correct:   34./  96. (35.42 %)
# Adapted Epoch Correct:   52./  96. (54.17 %)
# Corrupt Val Adapt Accuracy:  513./ 992. (0.5171370967741935)
# Corrupt Val Base Accuracy:  345./ 992. (0.3477822580645161)
# ===================================================================================================
# Running experiment for sample_size = 128
# Epoch 0
# Baseline Correct:   41./ 128. (32.03 %)
# Adapted Correct:   57./ 128. (44.53 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   57./ 128. (44.53 %)
# Epoch 1
# Baseline Correct:   82./ 256. (32.03 %)
# Adapted Correct:  121./ 256. (47.27 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   64./ 128. (50.00 %)
# Epoch 2
# Baseline Correct:  123./ 384. (32.03 %)
# Adapted Correct:  180./ 384. (46.88 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   59./ 128. (46.09 %)
# Epoch 3
# Baseline Correct:  164./ 512. (32.03 %)
# Adapted Correct:  238./ 512. (46.48 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 4
# Baseline Correct:  205./ 640. (32.03 %)
# Adapted Correct:  301./ 640. (47.03 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 5
# Baseline Correct:  246./ 768. (32.03 %)
# Adapted Correct:  361./ 768. (47.01 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 6
# Baseline Correct:  287./ 896. (32.03 %)
# Adapted Correct:  419./ 896. (46.76 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 7
# Baseline Correct:  328./1024. (32.03 %)
# Adapted Correct:  481./1024. (46.97 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 8
# Baseline Correct:  369./1152. (32.03 %)
# Adapted Correct:  541./1152. (46.96 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 9
# Baseline Correct:  410./1280. (32.03 %)
# Adapted Correct:  601./1280. (46.95 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 10
# Baseline Correct:  451./1408. (32.03 %)
# Adapted Correct:  657./1408. (46.66 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   56./ 128. (43.75 %)
# Epoch 11
# Baseline Correct:  492./1536. (32.03 %)
# Adapted Correct:  718./1536. (46.74 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 12
# Baseline Correct:  533./1664. (32.03 %)
# Adapted Correct:  778./1664. (46.75 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 13
# Baseline Correct:  574./1792. (32.03 %)
# Adapted Correct:  838./1792. (46.76 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 14
# Baseline Correct:  615./1920. (32.03 %)
# Adapted Correct:  898./1920. (46.77 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 15
# Baseline Correct:  656./2048. (32.03 %)
# Adapted Correct:  960./2048. (46.88 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 16
# Baseline Correct:  697./2176. (32.03 %)
# Adapted Correct: 1021./2176. (46.92 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 17
# Baseline Correct:  738./2304. (32.03 %)
# Adapted Correct: 1083./2304. (47.01 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 18
# Baseline Correct:  779./2432. (32.03 %)
# Adapted Correct: 1142./2432. (46.96 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   59./ 128. (46.09 %)
# Epoch 19
# Baseline Correct:  820./2560. (32.03 %)
# Adapted Correct: 1204./2560. (47.03 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 20
# Baseline Correct:  861./2688. (32.03 %)
# Adapted Correct: 1265./2688. (47.06 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 21
# Baseline Correct:  902./2816. (32.03 %)
# Adapted Correct: 1324./2816. (47.02 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   59./ 128. (46.09 %)
# Epoch 22
# Baseline Correct:  943./2944. (32.03 %)
# Adapted Correct: 1388./2944. (47.15 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   64./ 128. (50.00 %)
# Epoch 23
# Baseline Correct:  984./3072. (32.03 %)
# Adapted Correct: 1446./3072. (47.07 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 24
# Baseline Correct: 1025./3200. (32.03 %)
# Adapted Correct: 1502./3200. (46.94 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   56./ 128. (43.75 %)
# Epoch 25
# Baseline Correct: 1066./3328. (32.03 %)
# Adapted Correct: 1562./3328. (46.94 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 26
# Baseline Correct: 1107./3456. (32.03 %)
# Adapted Correct: 1620./3456. (46.88 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 27
# Baseline Correct: 1148./3584. (32.03 %)
# Adapted Correct: 1681./3584. (46.90 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 28
# Baseline Correct: 1189./3712. (32.03 %)
# Adapted Correct: 1743./3712. (46.96 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 29
# Baseline Correct: 1230./3840. (32.03 %)
# Adapted Correct: 1805./3840. (47.01 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   62./ 128. (48.44 %)
# Epoch 30
# Baseline Correct: 1271./3968. (32.03 %)
# Adapted Correct: 1865./3968. (47.00 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 31
# Baseline Correct: 1312./4096. (32.03 %)
# Adapted Correct: 1928./4096. (47.07 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 32
# Baseline Correct: 1353./4224. (32.03 %)
# Adapted Correct: 1991./4224. (47.14 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 33
# Baseline Correct: 1394./4352. (32.03 %)
# Adapted Correct: 2049./4352. (47.08 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 34
# Baseline Correct: 1435./4480. (32.03 %)
# Adapted Correct: 2109./4480. (47.08 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 35
# Baseline Correct: 1476./4608. (32.03 %)
# Adapted Correct: 2167./4608. (47.03 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   58./ 128. (45.31 %)
# Epoch 36
# Baseline Correct: 1517./4736. (32.03 %)
# Adapted Correct: 2227./4736. (47.02 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 37
# Baseline Correct: 1558./4864. (32.03 %)
# Adapted Correct: 2287./4864. (47.02 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   60./ 128. (46.88 %)
# Epoch 38
# Baseline Correct: 1599./4992. (32.03 %)
# Adapted Correct: 2350./4992. (47.08 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 39
# Baseline Correct: 1640./5120. (32.03 %)
# Adapted Correct: 2407./5120. (47.01 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   57./ 128. (44.53 %)
# Epoch 40
# Baseline Correct: 1681./5248. (32.03 %)
# Adapted Correct: 2468./5248. (47.03 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 41
# Baseline Correct: 1722./5376. (32.03 %)
# Adapted Correct: 2529./5376. (47.04 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 42
# Baseline Correct: 1763./5504. (32.03 %)
# Adapted Correct: 2592./5504. (47.09 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 43
# Baseline Correct: 1804./5632. (32.03 %)
# Adapted Correct: 2653./5632. (47.11 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   61./ 128. (47.66 %)
# Epoch 44
# Baseline Correct: 1845./5760. (32.03 %)
# Adapted Correct: 2716./5760. (47.15 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 45
# Baseline Correct: 1886./5888. (32.03 %)
# Adapted Correct: 2782./5888. (47.25 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   66./ 128. (51.56 %)
# Epoch 46
# Baseline Correct: 1927./6016. (32.03 %)
# Adapted Correct: 2845./6016. (47.29 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   63./ 128. (49.22 %)
# Epoch 47
# Baseline Correct: 1968./6144. (32.03 %)
# Adapted Correct: 2904./6144. (47.27 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   59./ 128. (46.09 %)
# Epoch 48
# Baseline Correct: 2009./6272. (32.03 %)
# Adapted Correct: 2969./6272. (47.34 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   65./ 128. (50.78 %)
# Epoch 49
# Baseline Correct: 2050./6400. (32.03 %)
# Adapted Correct: 3033./6400. (47.39 %)
# Baseline Epoch Correct:   41./ 128. (32.03 %)
# Adapted Epoch Correct:   64./ 128. (50.00 %)
# Corrupt Val Adapt Accuracy:  491./ 992. (0.4949596774193548)
# Corrupt Val Base Accuracy:  351./ 992. (0.3538306451612903)
# ===================================================================================================
# Running experiment for sample_size = 256
# Epoch 0
# Baseline Correct:   78./ 256. (30.47 %)
# Adapted Correct:  128./ 256. (50.00 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  128./ 256. (50.00 %)
# Epoch 1
# Baseline Correct:  156./ 512. (30.47 %)
# Adapted Correct:  254./ 512. (49.61 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  126./ 256. (49.22 %)
# Epoch 2
# Baseline Correct:  234./ 768. (30.47 %)
# Adapted Correct:  379./ 768. (49.35 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  125./ 256. (48.83 %)
# Epoch 3
# Baseline Correct:  312./1024. (30.47 %)
# Adapted Correct:  500./1024. (48.83 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  121./ 256. (47.27 %)
# Epoch 4
# Baseline Correct:  390./1280. (30.47 %)
# Adapted Correct:  623./1280. (48.67 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  123./ 256. (48.05 %)
# Epoch 5
# Baseline Correct:  468./1536. (30.47 %)
# Adapted Correct:  744./1536. (48.44 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  121./ 256. (47.27 %)
# Epoch 6
# Baseline Correct:  546./1792. (30.47 %)
# Adapted Correct:  876./1792. (48.88 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  132./ 256. (51.56 %)
# Epoch 7
# Baseline Correct:  624./2048. (30.47 %)
# Adapted Correct:  996./2048. (48.63 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:
%)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  129./ 256. (50.39 %)
# Epoch 30
# Baseline Correct: 2418./7936. (30.47 %)
# Adapted Correct: 3818./7936. (48.11 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  127./ 256. (49.61 %)
# Epoch 31
# Baseline Correct: 2496./8192. (30.47 %)
# Adapted Correct: 3940./8192. (48.10 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  122./ 256. (47.66 %)
# Epoch 32
# Baseline Correct: 2574./8448. (30.47 %)
# Adapted Correct: 4062./8448. (48.08 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  122./ 256. (47.66 %)
# Epoch 33
# Baseline Correct: 2652./8704. (30.47 %)
# Adapted Correct: 4186./8704. (48.09 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  124./ 256. (48.44 %)
# Epoch 34
# Baseline Correct: 2730./8960. (30.47 %)
# Adapted Correct: 4312./8960. (48.12 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  126./ 256. (49.22 %)
# Epoch 35
# Baseline Correct: 2808./9216. (30.47 %)
# Adapted Correct: 4438./9216. (48.16 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  126./ 256. (49.22 %)
# Epoch 36
# Baseline Correct: 2886./9472. (30.47 %)
# Adapted Correct: 4561./9472. (48.15 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  123./ 256. (48.05 %)
# Epoch 37
# Baseline Correct: 2964./9728. (30.47 %)
# Adapted Correct: 4688./9728. (48.19 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  127./ 256. (49.61 %)
# Epoch 38
# Baseline Correct: 3042./9984. (30.47 %)
# Adapted Correct: 4820./9984. (48.28 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  132./ 256. (51.56 %)
# Epoch 39
# Baseline Correct: 3120./10240. (30.47 %)
# Adapted Correct: 4950./10240. (48.34 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  130./ 256. (50.78 %)
# Epoch 40
# Baseline Correct: 3198./10496. (30.47 %)
# Adapted Correct: 5073./10496. (48.33 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  123./ 256. (48.05 %)
# Epoch 41
# Baseline Correct: 3276./10752. (30.47 %)
# Adapted Correct: 5196./10752. (48.33 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  123./ 256. (48.05 %)
# Epoch 42
# Baseline Correct: 3354./11008. (30.47 %)
# Adapted Correct: 5326./11008. (48.38 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  130./ 256. (50.78 %)
# Epoch 43
# Baseline Correct: 3432./11264. (30.47 %)
# Adapted Correct: 5449./11264. (48.38 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  123./ 256. (48.05 %)
# Epoch 44
# Baseline Correct: 3510./11520. (30.47 %)
# Adapted Correct: 5575./11520. (48.39 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  126./ 256. (49.22 %)
# Epoch 45
# Baseline Correct: 3588./11776. (30.47 %)
# Adapted Correct: 5702./11776. (48.42 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  127./ 256. (49.61 %)
# Epoch 46
# Baseline Correct: 3666./12032. (30.47 %)
# Adapted Correct: 5822./12032. (48.39 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  120./ 256. (46.88 %)
# Epoch 47
# Baseline Correct: 3744./12288. (30.47 %)
# Adapted Correct: 5950./12288. (48.42 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  128./ 256. (50.00 %)
# Epoch 48
# Baseline Correct: 3822./12544. (30.47 %)
# Adapted Correct: 6080./12544. (48.47 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  130./ 256. (50.78 %)
# Epoch 49
# Baseline Correct: 3900./12800. (30.47 %)
# Adapted Correct: 6211./12800. (48.52 %)
# Baseline Epoch Correct:   78./ 256. (30.47 %)
# Adapted Epoch Correct:  131./ 256. (51.17 %)
# Corrupt Val Adapt Accuracy:  539./ 992. (0.5433467741935484)
# ...
# Epoch 16
# Baseline Correct: 3417./8704. (39.26 %)
# Adapted Correct: 4399./8704. (50.54 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  257./ 512. (50.20 %)
# Epoch 17
# Baseline Correct: 3618./9216. (39.26 %)
# Adapted Correct: 4658./9216. (50.54 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  259./ 512. (50.59 %)
# Epoch 18
# Baseline Correct: 3819./9728. (39.26 %)
# Adapted Correct: 4925./9728. (50.63 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  267./ 512. (52.15 %)
# Epoch 19
# Baseline Correct: 4020./10240. (39.26 %)
# Adapted Correct: 5186./10240. (50.64 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  261./ 512. (50.98 %)
# Epoch 20
# Baseline Correct: 4221./10752. (39.26 %)
# Adapted Correct: 5450./10752. (50.69 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  264./ 512. (51.56 %)
# Epoch 21
# Baseline Correct: 4422./11264. (39.26 %)
# Adapted Correct: 5715./11264. (50.74 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  265./ 512. (51.76 %)
# Epoch 22
# Baseline Correct: 4623./11776. (39.26 %)
# Adapted Correct: 5975./11776. (50.74 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  260./ 512. (50.78 %)
# Epoch 23
# Baseline Correct: 4824./12288. (39.26 %)
# Adapted Correct: 6248./12288. (50.85 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  273./ 512. (53.32 %)
# Epoch 24
# Baseline Correct: 5025./12800. (39.26 %)
# Adapted Correct: 6511./12800. (50.87 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  263./ 512. (51.37 %)
# Epoch 25
# Baseline Correct: 5226./13312. (39.26 %)
# Adapted Correct: 6780./13312. (50.93 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  269./ 512. (52.54 %)
# Epoch 26
# Baseline Correct: 5427./13824. (39.26 %)
# Adapted Correct: 7052./13824. (51.01 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  272./ 512. (53.12 %)
# Epoch 27
# Baseline Correct: 5628./14336. (39.26 %)
# Adapted Correct: 7318./14336. (51.05 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  266./ 512. (51.95 %)
# Epoch 28
# Baseline Correct: 5829./14848. (39.26 %)
# Adapted Correct: 7584./14848. (51.08 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  266./ 512. (51.95 %)
# Epoch 29
# Baseline Correct: 6030./15360. (39.26 %)
# Adapted Correct: 7858./15360. (51.16 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  274./ 512. (53.52 %)
# Epoch 30
# Baseline Correct: 6231./15872. (39.26 %)
# Adapted Correct: 8123./15872. (51.18 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  265./ 512. (51.76 %)
# Epoch 31
# Baseline Correct: 6432./16384. (39.26 %)
# Adapted Correct: 8391./16384. (51.21 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  268./ 512. (52.34 %)
# Epoch 32
# Baseline Correct: 6633./16896. (39.26 %)
# Adapted Correct: 8668./16896. (51.30 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  277./ 512. (54.10 %)
# Epoch 33
# Baseline Correct: 6834./17408. (39.26 %)
# Adapted Correct: 8933./17408. (51.32 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  265./ 512. (51.76 %)
# Epoch 34
# Baseline Correct: 7035./17920. (39.26 %)
# Adapted Correct: 9201./17920. (51.34 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  268./ 512. (52.34 %)
# Epoch 35
# Baseline Correct: 7236./18432. (39.26 %)
# Adapted Correct: 9474./18432. (51.40 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  273./ 512. (53.32 %)
# Epoch 36
# Baseline Correct: 7437./18944. (39.26 %)
# Adapted Correct: 9738./18944. (51.40 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  264./ 512. (51.56 %)
# Epoch 37
# Baseline Correct: 7638./19456. (39.26 %)
# Adapted Correct: 10020./19456. (51.50 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  282./ 512. (55.08 %)
# Epoch 38
# Baseline Correct: 7839./19968. (39.26 %)
# Adapted Correct: 10290./19968. (51.53 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  270./ 512. (52.73 %)
# Epoch 39
# Baseline Correct: 8040./20480. (39.26 %)
# Adapted Correct: 10559./20480. (51.56 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  269./ 512. (52.54 %)
# Epoch 40
# Baseline Correct: 8241./20992. (39.26 %)
# Adapted Correct: 10833./20992. (51.61 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  274./ 512. (53.52 %)
# Epoch 41
# Baseline Correct: 8442./21504. (39.26 %)
# Adapted Correct: 11102./21504. (51.63 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  269./ 512. (52.54 %)
# Epoch 42
# Baseline Correct: 8643./22016. (39.26 %)
# Adapted Correct: 11370./22016. (51.64 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  268./ 512. (52.34 %)
# Epoch 43
# Baseline Correct: 8844./22528. (39.26 %)
# Adapted Correct: 11639./22528. (51.66 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  269./ 512. (52.54 %)
# Epoch 44
# Baseline Correct: 9045./23040. (39.26 %)
# Adapted Correct: 11907./23040. (51.68 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  268./ 512. (52.34 %)
# Epoch 45
# Baseline Correct: 9246./23552. (39.26 %)
# Adapted Correct: 12178./23552. (51.71 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  271./ 512. (52.93 %)
# Epoch 46
# Baseline Correct: 9447./24064. (39.26 %)
# Adapted Correct: 12446./24064. (51.72 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  268./ 512. (52.34 %)
# Epoch 47
# Baseline Correct: 9648./24576. (39.26 %)
# Adapted Correct: 12727./24576. (51.79 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  281./ 512. (54.88 %)
# Epoch 48
# Baseline Correct: 9849./25088. (39.26 %)
# Adapted Correct: 13001./25088. (51.82 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  274./ 512. (53.52 %)
# Epoch 49
# Baseline Correct: 10050./25600. (39.26 %)
# Adapted Correct: 13277./25600. (51.86 %)
# Baseline Epoch Correct:  201./ 512. (39.26 %)
# Adapted Epoch Correct:  276./ 512. (53.91 %)
# Corrupt Val Adapt Accuracy:  554./ 992. (0.5584677419354839)
# Corrupt Val Base Accuracy:  364./ 992. (0.36693548387096775)
# ===================================================================================================
# Running experiment for sample_size = 1028
# Epoch 0
# Baseline Correct:  371./1024. (36.23 %)
# Adapted Correct:  501./1024. (48.93 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  501./1024. (48.93 %)
# Epoch 1
# Baseline Correct:  741./2048. (36.18 %)
# Adapted Correct: 1018./2048. (49.71 %)
# Baseline Epoch Correct:  370./1024. (36.13 %)
# Adapted Epoch Correct:  517./1024. (50.49 %)
# Epoch 2
# Baseline Correct: 1113./3072. (36.23 %)
# Adapted Correct: 1534./3072. (49.93 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  516./1024. (50.39 %)
# Epoch 3
# Baseline Correct: 1484./4096. (36.23 %)
# Adapted Correct: 2056./4096. (50.20 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  522./1024. (50.98 %)
# Epoch 4
# Baseline Correct: 1855./5120. (36.23 %)
# Adapted Correct: 2583./5120. (50.45 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  527./1024. (51.46 %)
# Epoch 5
# Baseline Correct: 2224./6144. (36.20 %)
# Adapted Correct: 3118./6144. (50.75 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  535./1024. (52.25 %)
# Epoch 6
# Baseline Correct: 2593./7168. (36.17 %)
# Adapted Correct: 3642./7168. (50.81 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  524./1024. (51.17 %)
# Epoch 7
# Baseline Correct: 2964./8192. (36.18 %)
# Adapted Correct: 4157./8192. (50.74 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  515./1024. (50.29 %)
# Epoch 8
# Baseline Correct: 3335./9216. (36.19 %)
# Adapted Correct: 4672./9216. (50.69 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  515./1024. (50.29 %)
# Epoch 9
# Baseline Correct: 3706./10240. (36.19 %)
# Adapted Correct: 5201./10240. (50.79 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  529./1024. (51.66 %)
# Epoch 10
# Baseline Correct: 4077./11264. (36.19 %)
# Adapted Correct: 5736./11264. (50.92 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  535./1024. (52.25 %)
# Epoch 11
# Baseline Correct: 4447./12288. (36.19 %)
# Adapted Correct: 6279./12288. (51.10 %)
# Baseline Epoch Correct:  370./1024. (36.13 %)
# Adapted Epoch Correct:  543./1024. (53.03 %)
# Epoch 12
# Baseline Correct: 4817./13312. (36.19 %)
# Adapted Correct: 6804./13312. (51.11 %)
# Baseline Epoch Correct:  370./1024. (36.13 %)
# Adapted Epoch Correct:  525./1024. (51.27 %)
# Epoch 13
# Baseline Correct: 5187./14336. (36.18 %)
# Adapted Correct: 7340./14336. (51.20 %)
# Baseline Epoch Correct:  370./1024. (36.13 %)
# Adapted Epoch Correct:  536./1024. (52.34 %)
# Epoch 14
# Baseline Correct: 5559./15360. (36.19 %)
# Adapted Correct: 7884./15360. (51.33 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  544./1024. (53.12 %)
# Epoch 15
# Baseline Correct: 5930./16384. (36.19 %)
# Adapted Correct: 8427./16384. (51.43 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  543./1024. (53.03 %)
# Epoch 16
# Baseline Correct: 6299./17408. (36.18 %)
# Adapted Correct: 8970./17408. (51.53 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  543./1024. (53.03 %)
# Epoch 17
# Baseline Correct: 6668./18432. (36.18 %)
# Adapted Correct: 9506./18432. (51.57 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  536./1024. (52.34 %)
# Epoch 18
# Baseline Correct: 7036./19456. (36.16 %)
# Adapted Correct: 10049./19456. (51.65 %)
# Baseline Epoch Correct:  368./1024. (35.94 %)
# Adapted Epoch Correct:  543./1024. (53.03 %)
# Epoch 19
# Baseline Correct: 7408./20480. (36.17 %)
# Adapted Correct: 10599./20480. (51.75 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  550./1024. (53.71 %)
# Epoch 20
# Baseline Correct: 7780./21504. (36.18 %)
# Adapted Correct: 11149./21504. (51.85 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  550./1024. (53.71 %)
# Epoch 21
# Baseline Correct: 8151./22528. (36.18 %)
# Adapted Correct: 11701./22528. (51.94 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  552./1024. (53.91 %)
# Epoch 22
# Baseline Correct: 8522./23552. (36.18 %)
# Adapted Correct: 12253./23552. (52.03 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  552./1024. (53.91 %)
# Epoch 23
# Baseline Correct: 8893./24576. (36.19 %)
# Adapted Correct: 12808./24576. (52.12 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  555./1024. (54.20 %)
# Epoch 24
# Baseline Correct: 9263./25600. (36.18 %)
# Adapted Correct: 13362./25600. (52.20 %)
# Baseline Epoch Correct:  370./1024. (36.13 %)
# Adapted Epoch Correct:  554./1024. (54.10 %)
# Epoch 25
# Baseline Correct: 9635./26624. (36.19 %)
# Adapted Correct: 13920./26624. (52.28 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  558./1024. (54.49 %)
# Epoch 26
# Baseline Correct: 10007./27648. (36.19 %)
# Adapted Correct: 14472./27648. (52.34 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  552./1024. (53.91 %)
# Epoch 27
# Baseline Correct: 10378./28672. (36.20 %)
# Adapted Correct: 15029./28672. (52.42 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  557./1024. (54.39 %)
# Epoch 28
# Baseline Correct: 10747./29696. (36.19 %)
# Adapted Correct: 15578./29696. (52.46 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  549./1024. (53.61 %)
# Epoch 29
# Baseline Correct: 11119./30720. (36.19 %)
# Adapted Correct: 16137./30720. (52.53 %)
# Baseline Epoch Correct:  372./1024. (36.33 %)
# Adapted Epoch Correct:  559./1024. (54.59 %)
# Epoch 30
# Baseline Correct: 11488./31744. (36.19 %)
# Adapted Correct: 16688./31744. (52.57 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  551./1024. (53.81 %)
# Epoch 31
# Baseline Correct: 11859./32768. (36.19 %)
# Adapted Correct: 17239./32768. (52.61 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  551./1024. (53.81 %)
# Epoch 32
# Baseline Correct: 12230./33792. (36.19 %)
# Adapted Correct: 17791./33792. (52.65 %)
# Baseline Epoch Correct:  371./1024. (36.23 %)
# Adapted Epoch Correct:  552./1024. (53.91 %)
# Epoch 33
# Baseline Correct: 12599./34816. (36.19 %)
# Adapted Correct: 18362./34816. (52.74 %)
# Baseline Epoch Correct:  369./1024. (36.04 %)
# Adapted Epoch Correct:  571./1024. (55.76 %)
# Epoch 34
# Exception ignored in: <function _releaseLock at 0x7f513d8c35e0>
# Traceback (most recent call last):
#   File "/home/zw2774/bin/anaconda3/lib/python3.9/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1010         try:
# -> 1011             data = self._data_queue.get(timeout=timeout)
#    1012             return (True, data)
#
# ~/bin/anaconda3/lib/python3.9/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
# --> 179                         raise Empty
#     180                     self.not_empty.wait(remaining)
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_48493/3706622906.py in <module>
#      11
#      12     base_acc, base_acc_epoch, adapted_train_acc_overall, adapted_train_acc_per_epoch, adapted_train_acc_per_iter, \
# ---> 13     model, baseline, training_time = evaluate(corrupted_dataloaders[0]['train'], num_epochs=50)
#      14
#      15     ## evaluate on val set
#
# /tmp/ipykernel_48493/444841239.py in evaluate(data_loader, datadir, num_epochs, batch_size, learning_rate, gce_q)
#      75         b_correct_epoch, num_correct_epoch, num_samples_epoch = 0., 0., 0.
#      76
# ---> 77         for images, targets in data_loader:
#      78
#      79             logits = model(images.to(device))
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1205
#    1206             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1207             idx, data = self._get_data()
#    1208             self._tasks_outstanding -= 1
#    1209             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1161         elif self._pin_memory:
#    1162             while self._pin_memory_thread.is_alive():
# -> 1163                 success, data = self._try_get_data()
#    1164                 if success:
#    1165                     return data
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1022             if len(failed_workers) > 0:
#    1023                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1024                 raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1025             if isinstance(e, queue.Empty):
#    1026                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 46908, 46909, 46910, 46911, 46912, 46913, 46914, 46915, 46916, 46917, 46918, 46919, 46920, 46921, 46922, 46923, 46924, 46925, 46926, 46927, 46928, 46929, 46930, 46931, 46932, 46933, 46934) exited unexpectedly

# %%
len(acc_record_samplesize[32][2])
# Out:
# 500

# %%
## Saving the recorded performances
import pickle

# with open('sample_size_ablation.pkl', 'wb') as f:
#     pickle.dump(acc_record_samplesize, f)
        
with open('sample_size_ablation.pkl', 'rb') as f:
    acc_record_samplesize = pickle.load(f)

# %%
## Plot the acc boost over iterations
fig, ax = plt.subplots(6, figsize = [10,50])

subplot_ind = 0

for key, (base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, _, _, training_time) in acc_record_samplesize.items():
    

    ax[subplot_ind].plot(base_acc, label='baseline acc')
#     ax[subplot_ind].plot(adapted_online_acc_overall, label='adapted acc overall')
    ax[subplot_ind].plot(adapted_train_acc_per_epoch, label='adapted acc per epoch')
#     ax[subplot_ind].plot(adapted_online_acc_per_iter, label='adapted acc per batch')
    ax[subplot_ind].legend()
    ax[subplot_ind].set_title('Training accuracies over iterations, severity = 3, sample_size=' + str(key))
    ax[subplot_ind].set_ylim([0, 0.8])
    ax[subplot_ind].set(xlabel="Iterations", ylabel="Accuracy")
    
    subplot_ind += 1

plt.show()

# %%
## Plot the train vs val comparison across all sample sizes
sample_sizes = [32, 64, 96, 128, 256, 512]
base_training_acc = [acc_record_samplesize[ss][1][-1] for ss in sample_sizes]
adapted_training_acc = [acc_record_samplesize[ss][3][-1] for ss in sample_sizes]

base_val_acc = [acc_record_samplesize[ss][5] for ss in sample_sizes]
adapted_val_acc = [acc_record_samplesize[ss][6] for ss in sample_sizes]

plt.plot(base_training_acc, label = 'base_training_acc')
plt.plot(adapted_training_acc, label = 'adapted_training_acc')
plt.plot(base_val_acc, label = 'base_val_acc')
plt.plot(adapted_val_acc, label = 'adapted_val_acc')

plt.title('base and adapted acc on training & val dataset')
plt.xticks([0, 1, 2, 3, 4, 5], sample_sizes)

plt.legend()
plt.show()

# %% [markdown]
# ### 3. Batch Size

# %%
acc_record_few_shot = {} #acc_record_samplesize[ss] = [base_acc], [base_acc_epoch], [adapted_online_acc_overall], [adapted_train_acc_per_epoch], [adapted_online_acc_per_batch], base_val_acc, adapted_val_acc, [training_time]
batch_sizes = [32, 16, 8, 4, 2, 1]
sample_size = [32, 16, 8, 4, 2, 1]

for bs in batch_sizes:

    print("Running experiment for batch_size =", bs)

    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, 3, bs, bs)

    base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, \
    adapted_online_acc_per_iter, model, baseline, training_time = evaluate(corrupted_dataloaders[0]['train'], num_epochs=5)
    
    ## evaluate on val set
    model.eval()
    baseline.eval()
    with torch.no_grad():
        base_val_correct, crpt_val_correct, crpt_val_samples = 0, 0, 0
        for images, labels in corrupted_dataloaders[0]['val']:
            labels = labels.to(device)
            outputs = model(images.to(device))
            _, predicted = torch.max(outputs.data, 1)
            crpt_val_correct += (predicted == labels).sum().item()
            crpt_val_samples += len(labels)

            b_outputs = baseline(images.to(device))
            _, b_predicted = torch.max(b_outputs.data, 1)
            base_val_correct += (b_predicted == labels).sum().item()


    print(f"Corrupt Val Adapt Accuracy: {crpt_val_correct:#5.0f}/{crpt_val_samples:#5.0f} ({crpt_val_correct / crpt_val_samples})")
    print(f"Corrupt Val Base Accuracy: {base_val_correct:#5.0f}/{crpt_val_samples:#5.0f} ({base_val_correct / crpt_val_samples})")

    acc_record_few_shot[bs] = [base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, (base_val_correct/crpt_val_samples), (crpt_val_correct/crpt_val_samples), training_time]
    
    print("===================================================================================================")
# Out:
# Running experiment for batch_size = 32
# Epoch 0
# Baseline Correct:   11./  32. (34.38 %)
# Adapted Correct:   17./  32. (53.12 %)
# Baseline Epoch Correct:   11./  32. (34.38 %)
# Adapted Epoch Correct:   17./  32. (53.12 %)
# Epoch 1
# Baseline Correct:   22./  64. (34.38 %)
# Adapted Correct:   34./  64. (53.12 %)
# Baseline Epoch Correct:   11./  32. (34.38 %)
# Adapted Epoch Correct:   17./  32. (53.12 %)
# Epoch 2
# Baseline Correct:   33./  96. (34.38 %)
# Adapted Correct:   51./  96. (53.12 %)
# Baseline Epoch Correct:   11./  32. (34.38 %)
# Adapted Epoch Correct:   17./  32. (53.12 %)
# Epoch 3
# Baseline Correct:   44./ 128. (34.38 %)
# Adapted Correct:   68./ 128. (53.12 %)
# Baseline Epoch Correct:   11./  32. (34.38 %)
# Adapted Epoch Correct:   17./  32. (53.12 %)
# Epoch 4
# Baseline Correct:   55./ 160. (34.38 %)
# Adapted Correct:   85./ 160. (53.12 %)
# Baseline Epoch Correct:   11./  32. (34.38 %)
# Adapted Epoch Correct:   17./  32. (53.12 %)
# Corrupt Val Adapt Accuracy:  421./ 992. (0.42439516129032256)
# Corrupt Val Base Accuracy:  348./ 992. (0.35080645161290325)
# ===================================================================================================
# Running experiment for batch_size = 16
# Epoch 0
# Baseline Correct:    7./  16. (43.75 %)
# Adapted Correct:   10./  16. (62.50 %)
# Baseline Epoch Correct:    7./  16. (43.75 %)
# Adapted Epoch Correct:   10./  16. (62.50 %)
# Epoch 1
# Baseline Correct:   14./  32. (43.75 %)
# Adapted Correct:   20./  32. (62.50 %)
# Baseline Epoch Correct:    7./  16. (43.75 %)
# Adapted Epoch Correct:   10./  16. (62.50 %)
# Epoch 2
# Baseline Correct:   21./  48. (43.75 %)
# Adapted Correct:   30./  48. (62.50 %)
# Baseline Epoch Correct:    7./  16. (43.75 %)
# Adapted Epoch Correct:   10./  16. (62.50 %)
# Epoch 3
# Baseline Correct:   28./  64. (43.75 %)
# Adapted Correct:   40./  64. (62.50 %)
# Baseline Epoch Correct:    7./  16. (43.75 %)
# Adapted Epoch Correct:   10./  16. (62.50 %)
# Epoch 4
# Baseline Correct:   35./  80. (43.75 %)
# Adapted Correct:   50./  80. (62.50 %)
# Baseline Epoch Correct:    7./  16. (43.75 %)
# Adapted Epoch Correct:   10./  16. (62.50 %)
# Corrupt Val Adapt Accuracy:  413./ 992. (0.4163306451612903)
# Corrupt Val Base Accuracy:  355./ 992. (0.35786290322580644)
# ===================================================================================================
# Running experiment for batch_size = 8
# Epoch 0
# Baseline Correct:    2./   8. (25.00 %)
# Adapted Correct:    5./   8. (62.50 %)
# Baseline Epoch Correct:    2./   8. (25.00 %)
# Adapted Epoch Correct:    5./   8. (62.50 %)
# Epoch 1
# Baseline Correct:    4./  16. (25.00 %)
# Adapted Correct:   10./  16. (62.50 %)
# Baseline Epoch Correct:    2./   8. (25.00 %)
# Adapted Epoch Correct:    5./   8. (62.50 %)
# Epoch 2
# Baseline Correct:    6./  24. (25.00 %)
# Adapted Correct:   15./  24. (62.50 %)
# Baseline Epoch Correct:    2./   8. (25.00 %)
# Adapted Epoch Correct:    5./   8. (62.50 %)
# Epoch 3
# Baseline Correct:    8./  32. (25.00 %)
# Adapted Correct:   20./  32. (62.50 %)
# Baseline Epoch Correct:    2./   8. (25.00 %)
# Adapted Epoch Correct:    5./   8. (62.50 %)
# Epoch 4
# Baseline Correct:   10./  40. (25.00 %)
# Adapted Correct:   25./  40. (62.50 %)
# Baseline Epoch Correct:    2./   8. (25.00 %)
# Adapted Epoch Correct:    5./   8. (62.50 %)
# Corrupt Val Adapt Accuracy:  422./1000. (0.422)
# Corrupt Val Base Accuracy:  344./1000. (0.344)
# ===================================================================================================
# Running experiment for batch_size = 4
# Epoch 0
# Baseline Correct:    1./   4. (25.00 %)
# Adapted Correct:    0./   4. (0.00 %)
# Baseline Epoch Correct:    1./   4. (25.00 %)
# Adapted Epoch Correct:    0./   4. (0.00 %)
# Epoch 1
# Baseline Correct:    2./   8. (25.00 %)
# Adapted Correct:    0./   8. (0.00 %)
# Baseline Epoch Correct:    1./   4. (25.00 %)
# Adapted Epoch Correct:    0./   4. (0.00 %)
# Epoch 2
# Baseline Correct:    3./  12. (25.00 %)
# Adapted Correct:    0./  12. (0.00 %)
# Baseline Epoch Correct:    1./   4. (25.00 %)
# Adapted Epoch Correct:    0./   4. (0.00 %)
# Epoch 3
# Baseline Correct:    4./  16. (25.00 %)
# Adapted Correct:    0./  16. (0.00 %)
# Baseline Epoch Correct:    1./   4. (25.00 %)
# Adapted Epoch Correct:    0./   4. (0.00 %)
# Epoch 4
# Baseline Correct:    5./  20. (25.00 %)
# Adapted Correct:    0./  20. (0.00 %)
# Baseline Epoch Correct:    1./   4. (25.00 %)
# Adapted Epoch Correct:    0./   4. (0.00 %)
# Corrupt Val Adapt Accuracy:  411./1000. (0.411)
# Corrupt Val Base Accuracy:  354./1000. (0.354)
# ===================================================================================================
# Running experiment for batch_size = 2
# Epoch 0
# Baseline Correct:    1./   2. (50.00 %)
# Adapted Correct:    0./   2. (0.00 %)
# Baseline Epoch Correct:    1./   2. (50.00 %)
# Adapted Epoch Correct:    0./   2. (0.00 %)
# Epoch 1
# Baseline Correct:    2./   4. (50.00 %)
# Adapted Correct:    0./   4. (0.00 %)
# Baseline Epoch Correct:    1./   2. (50.00 %)
# Adapted Epoch Correct:    0./   2. (0.00 %)
# Epoch 2
# Baseline Correct:    3./   6. (50.00 %)
# Adapted Correct:    0./   6. (0.00 %)
# Baseline Epoch Correct:    1./   2. (50.00 %)
# Adapted Epoch Correct:    0./   2. (0.00 %)
# Epoch 3
# Baseline Correct:    4./   8. (50.00 %)
# Adapted Correct:    0./   8. (0.00 %)
# Baseline Epoch Correct:    1./   2. (50.00 %)
# Adapted Epoch Correct:    0./   2. (0.00 %)
# Epoch 4
# Baseline Correct:    5./  10. (50.00 %)
# Adapted Correct:    0./  10. (0.00 %)
# Baseline Epoch Correct:    1./   2. (50.00 %)
# Adapted Epoch Correct:    0./   2. (0.00 %)
# Corrupt Val Adapt Accuracy:  414./1000. (0.414)
# Corrupt Val Base Accuracy:  351./1000. (0.351)
# ===================================================================================================
# Running experiment for batch_size = 1
# Epoch 0
# Baseline Correct:    1./   1. (100.00 %)
# Adapted Correct:    0./   1. (0.00 %)
# Baseline Epoch Correct:    1./   1. (100.00 %)
# Adapted Epoch Correct:    0./   1. (0.00 %)
# Epoch 1
# Baseline Correct:    2./   2. (100.00 %)
# Adapted Correct:    0./   2. (0.00 %)
# Baseline Epoch Correct:    1./   1. (100.00 %)
# Adapted Epoch Correct:    0./   1. (0.00 %)
# Epoch 2
# Baseline Correct:    3./   3. (100.00 %)
# Adapted Correct:    0./   3. (0.00 %)
# Baseline Epoch Correct:    1./   1. (100.00 %)
# Adapted Epoch Correct:    0./   1. (0.00 %)
# Epoch 3
# Baseline Correct:    4./   4. (100.00 %)
# Adapted Correct:    0./   4. (0.00 %)
# Baseline Epoch Correct:    1./   1. (100.00 %)
# Adapted Epoch Correct:    0./   1. (0.00 %)
# Epoch 4
# Baseline Correct:    5./   5. (100.00 %)
# Adapted Correct:    0./   5. (0.00 %)
# Baseline Epoch Correct:    1./   1. (100.00 %)
# Adapted Epoch Correct:    0./   1. (0.00 %)
# Corrupt Val Adapt Accuracy:  351./1000. (0.351)
# Corrupt Val Base Accuracy:  333./1000. (0.333)
# ===================================================================================================

# %%
## Saving the recorded performance dictionary
import pickle

with open('batch_size_ablation.pkl', 'wb') as f:
    pickle.dump(acc_record_batchsize, f)
        
with open('batch_size_ablation.pkl', 'rb') as f:
    acc_record_batchsize = pickle.load(f)

# %%
acc_record_few_shot
# Out:
# {32: [[tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438)],
#   [tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438),
#    tensor(0.3438)],
#   [tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312)],
#   [tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312)],
#   [tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312),
#    tensor(0.5312)],
#   0.35080645161290325,
#   0.42439516129032256,
#   [3.197472095489502,
#    6.442323446273804,
#    9.691792011260986,
#    12.92820954322815,
#    16.184421062469482]],
#  16: [[tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375)],
#   [tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375),
#    tensor(0.4375)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   0.35786290322580644,
#   0.4163306451612903,
#   [3.095400094985962,
#    6.161520957946777,
#    9.277275085449219,
#    12.291375637054443,
#    15.24584174156189]],
#  8: [[tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500)],
#   [tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   [tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250),
#    tensor(0.6250)],
#   0.344,
#   0.422,
#   [3.0561745166778564,
#    6.140369653701782,
#    9.246338129043579,
#    12.352749347686768,
#    15.42563247680664]],
#  4: [[tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500)],
#   [tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500),
#    tensor(0.2500)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   0.354,
#   0.411,
#   [3.0002026557922363,
#    6.17054009437561,
#    9.19596815109253,
#    12.197290182113647,
#    15.188074827194214]],
#  2: [[tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000)],
#   [tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000),
#    tensor(0.5000)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   0.351,
#   0.414,
#   [3.0262930393218994,
#    6.041144609451294,
#    9.087446451187134,
#    12.128547430038452,
#    15.181968688964844]],
#  1: [[tensor(1.), tensor(1.), tensor(1.), tensor(1.), tensor(1.)],
#   [tensor(1.), tensor(1.), tensor(1.), tensor(1.), tensor(1.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)],
#   0.333,
#   0.351,
#   [2.9885716438293457,
#    5.960597515106201,
#    8.930503129959106,
#    11.961477756500244,
#    14.905333042144775]]}

# %%
fig, ax = plt.subplots(6, figsize = [10,40])

subplot_ind = 0

for key, (base_acc, base_acc_epoch, adapted_online_acc_overall, adapted_train_acc_per_epoch, adapted_online_acc_per_iter, base_val_acc , adapted_val_acc, time) in acc_record_few_shot.items():
    

    ax[subplot_ind].plot(base_acc, label='baseline acc training')
    ax[subplot_ind].plot(adapted_online_acc_overall, label='adapted acc training')
    ax[subplot_ind].plot([base_val_acc] * 5, label='baseline acc val')
    ax[subplot_ind].plot([adapted_val_acc] * 5, label='adapted acc val')
    
    
#     ax[subplot_ind].plot(adapted_online_acc_per_batch, label='adapted acc per batch')
    ax[subplot_ind].legend()
    ax[subplot_ind].set_title('Training accuracies over iterations, severity = 3, batch_size=' + str(key))
    ax[subplot_ind].set_ylim([0, 0.8])
    ax[subplot_ind].set(xlabel="Iterations", ylabel="Accuracy")
    
    subplot_ind += 1

plt.show()

# %%
fig, ax = plt.subplots(4, figsize = [10,40])
subplot_ind = 0
acc_record = {}
for batch_size in [32, 64, 96]:
    
    print("Running experiment for batch_size =", batch_size)
    
    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, 3, batch_size, 512)

    base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch = evaluate(corrupted_dataloaders[0]['train'], num_epochs=5)
    acc_record[batch_size] = base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch

#     plt.rcParams["figure.figsize"] = (20,20)

    ax[subplot_ind].plot(base_acc, label='baseline acc')
    ax[subplot_ind].plot(adapted_online_acc_overall, label='adapted acc overall')
    ax[subplot_ind].plot(adapted_online_acc_per_batch, label='adapted acc per batch')
    ax[subplot_ind].legend()
    ax[subplot_ind].set_title('Training accuracies over iterations, batch_size = ' + str(batch_size))
    
    subplot_ind += 1

plt.show()
# Out:
# Running experiment for batch_size = 32
# Epoch 0
# Baseline Correct:  142./ 512. (27.73 %)
# Adapted Correct:  143./ 512. (27.93 %)
# Epoch 1
# Baseline Correct:  287./1024. (28.03 %)
# Adapted Correct:  289./1024. (28.22 %)
# Epoch 2
# Baseline Correct:  438./1536. (28.52 %)
# Adapted Correct:  443./1536. (28.84 %)
# Epoch 3
# Baseline Correct:  575./2048. (28.08 %)
# Adapted Correct:  583./2048. (28.47 %)
# Epoch 4
# Baseline Correct:  724./2560. (28.28 %)
# Adapted Correct:  736./2560. (28.75 %)
# Running experiment for batch_size = 64
# Epoch 0
# Baseline Correct:  156./ 512. (30.47 %)
# Adapted Correct:  156./ 512. (30.47 %)
# Epoch 1
# Baseline Correct:  305./1024. (29.79 %)
# Adapted Correct:  305./1024. (29.79 %)
# Epoch 2
# Baseline Correct:  462./1536. (30.08 %)
# Adapted Correct:  463./1536. (30.14 %)
# Epoch 3
# Baseline Correct:  626./2048. (30.57 %)
# Adapted Correct:  631./2048. (30.81 %)
# Epoch 4
# Baseline Correct:  771./2560. (30.12 %)
# Adapted Correct:  779./2560. (30.43 %)
# Running experiment for batch_size = 96
# Epoch 0
# Baseline Correct:  127./ 480. (26.46 %)
# Adapted Correct:  128./ 480. (26.67 %)
# Epoch 1
# Baseline Correct:  262./ 960. (27.29 %)
# Adapted Correct:  263./ 960. (27.40 %)
# Epoch 2
# Baseline Correct:  395./1440. (27.43 %)
# Adapted Correct:  396./1440. (27.50 %)
# Epoch 3
# Baseline Correct:  525./1920. (27.34 %)
# Adapted Correct:  527./1920. (27.45 %)
# Epoch 4
# Baseline Correct:  662./2400. (27.58 %)
# Adapted Correct:  665./2400. (27.71 %)

# %%
acc_record = {}
for batch_size in [96]:
    
    print("Running experiment for batch_size =", batch_size)
    
    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, 3, batch_size, 512)

    base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch = evaluate(corrupted_dataloaders[0]['train'], num_epochs=50)
    acc_record[batch_size] = base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch
# Out:
# Running experiment for batch_size = 96
# Epoch 0
# Baseline Correct:  147./ 480. (30.62 %)
# Adapted Correct:  148./ 480. (30.83 %)
# Epoch 1
# Baseline Correct:  304./ 960. (31.67 %)
# Adapted Correct:  306./ 960. (31.88 %)
# Epoch 2
# Baseline Correct:  457./1440. (31.74 %)
# Adapted Correct:  459./1440. (31.88 %)
# Epoch 3
# Baseline Correct:  598./1920. (31.15 %)
# Adapted Correct:  601./1920. (31.30 %)
# Epoch 4
# Baseline Correct:  736./2400. (30.67 %)
# Adapted Correct:  740./2400. (30.83 %)
# Epoch 5
# Baseline Correct:  893./2880. (31.01 %)
# Adapted Correct:  898./2880. (31.18 %)
# Epoch 6
# Baseline Correct: 1023./3360. (30.45 %)
# Adapted Correct: 1030./3360. (30.65 %)
# Epoch 7
# Baseline Correct: 1173./3840. (30.55 %)
# Adapted Correct: 1183./3840. (30.81 %)
# Epoch 8
# Baseline Correct: 1323./4320. (30.62 %)
# Adapted Correct: 1334./4320. (30.88 %)
# Epoch 9
# Baseline Correct: 1468./4800. (30.58 %)
# Adapted Correct: 1480./4800. (30.83 %)
# Epoch 10
# Baseline Correct: 1622./5280. (30.72 %)
# Adapted Correct: 1638./5280. (31.02 %)
# Epoch 11
# Baseline Correct: 1784./5760. (30.97 %)
# Adapted Correct: 1801./5760. (31.27 %)
# Epoch 12
# Baseline Correct: 1923./6240. (30.82 %)
# Adapted Correct: 1945./6240. (31.17 %)
# Epoch 13
# Baseline Correct: 2075./6720. (30.88 %)
# Adapted Correct: 2103./6720. (31.29 %)
# Epoch 14
# Baseline Correct: 2223./7200. (30.88 %)
# Adapted Correct: 2256./7200. (31.33 %)
# Epoch 15
# Baseline Correct: 2365./7680. (30.79 %)
# Adapted Correct: 2404./7680. (31.30 %)
# Epoch 16
# Baseline Correct: 2508./8160. (30.74 %)
# Adapted Correct: 2552./8160. (31.27 %)
# Epoch 17
# Baseline Correct: 2666./8640. (30.86 %)
# Adapted Correct: 2717./8640. (31.45 %)
# Epoch 18
# Baseline Correct: 2827./9120. (31.00 %)
# Adapted Correct: 2885./9120. (31.63 %)
# Epoch 19
# Baseline Correct: 2985./9600. (31.09 %)
# Adapted Correct: 3051./9600. (31.78 %)
# Epoch 20
# Baseline Correct: 3131./10080. (31.06 %)
# Adapted Correct: 3205./10080. (31.80 %)
# Epoch 21
# Baseline Correct: 3281./10560. (31.07 %)
# Adapted Correct: 3365./10560. (31.87 %)
# Epoch 22
# Adapted Correct: 7899./24000. (32.91 %)

# %%
fig, ax = plt.subplots(4, figsize = [10,40])

subplot_ind = 0

for key, (base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch) in acc_record.items():
    

    ax[subplot_ind].plot(base_acc, label='baseline acc')
    ax[subplot_ind].plot(adapted_online_acc_overall, label='adapted acc overall')
    ax[subplot_ind].plot(adapted_online_acc_per_batch, label='adapted acc per batch')
    ax[subplot_ind].legend()
    ax[subplot_ind].set_title('Training accuracies over iterations, batch_size = ' + str(batch_size))
    
    subplot_ind += 1

plt.show()

# %%
## running the original experiment using the paper hyperparams
acc_record_sev = {}
batch_size = 96
for severity in range(1, 6):
    
    print("Running experiment for severity =", severity)
    
    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, severity, batch_size, 49000)

    base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch = evaluate(corrupted_dataloaders[0]['train'])
    acc_record_sev[severity] = base_acc, adapted_online_acc_overall, adapted_online_acc_per_batch
# Out:
# Running experiment for severity = 1
# Epoch 0

# %% [markdown]
# # TTA - Robust Pseudo label

# %%
import time

# %%
import torch
from torchvision import models, datasets, transforms

def gce(logits, target, q = 0.8):
    """ Generalized cross entropy.
    
    Reference: https://arxiv.org/abs/1805.07836
    """
    probs = torch.nn.functional.softmax(logits, dim=1)
    probs_with_correct_idx = probs.index_select(-1, target).diag()
    loss = (1. - probs_with_correct_idx**q) / q
    return loss.mean()

def adapt_batchnorm(model):
    model.eval()
    parameters = []
    for module in model.modules():
        if isinstance(module, torch.nn.BatchNorm2d):
            parameters.extend(module.parameters())
            module.train()
    return parameters


# ---

# %%
def adapt(
#         datadir = '/data/imagenetc/gaussian_blur/3',
        model,
        dataloader,
        num_epochs = 1, # followed their findings in the paper
        batch_size = 32,
        learning_rate = 0.75e-3,
        gce_q = 0.8,
    ):
    
#     model = models.resnet50(pretrained = True).to(device)
    parameters = adapt_batchnorm(model)
#     # TODO change this loader
#     val_loader = get_dataset_loader(
#         datadir,
#         batch_size = batch_size,
#         shuffle = True
#     )
    optimizer = torch.optim.SGD(
        model.parameters(), lr = learning_rate
    )
    print('DEBUGGING: model.parameters()',model.parameters())
    print('DEBUGGING: parameters',parameters)
    
    num_correct, num_samples = 0., 0.
    for epoch in range(num_epochs):
        predictions = []
#         batch_inf_times = []
        batch_accs = []
        for images, labels in dataloader:
#             start = time.time()
            
            outputs = model(images.to(device))
            predictions = outputs.argmax(dim = 1)
#             _, predicted = torch.max(outputs.data, 1)

#             inference_time = time.time() - start
#             batch_inf_times.append(inference_time)
           
#             batch_accuracy = ((predicted == labels).sum().item()) / labels.size(0)
#             batch_accs.append(batch_accuracy)
            
            # TODO: in our scenario, do we want to revert back to original model after adapting in each step?
            loss = gce(outputs, predictions, q = gce_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            num_correct += (predictions.detach().cpu() == labels).float().sum()
            num_samples += len(labels)
            print(f"Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
            
    return model, (num_correct/num_samples)

# %%
target_sizes = [32, 64, 128, 256, 512, 1000]
severity = [1,2,3,4,5]

rpl_corrupt_train_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))
rpl_corrupt_val_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))
rpl_ref_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))


rpl_adpt_times = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))

# %%
for severity_ind in range(len(severity)):
    for ts_ind in range(len(target_sizes)):
        ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
        = get_imagenetc(imagebase, severity[severity_ind], 32, target_sizes[ts_ind])
        
        # TODO: wait, shouldn't I use a new model for every corruption?
        # uh bug!
        model = models.resnet50(pretrained=True)
        model.to(device)
        # adapt the model using the rpl methods
        # evaluate the adapted model on the test corrupted (target) dataset & the reference (source) dataset
        for cor_ind in range(len(corrupted_dataloaders)):
            
            print(f'## Experiment: Severity = {severity[severity_ind]}, target_size = {target_sizes[ts_ind]}, corruption = {corruption[cor_ind]}')

            # adapt the model
            start = time.time()
            model, train_acc = adapt(model, corrupted_dataloaders[cor_ind]['train'])
            adapt_time = time.time() - start
            print(f"Adaptation time: {adapt_time}")
            
            rpl_adpt_times[cor_ind, severity_ind, ts_ind] = adapt_time
            rpl_corrupt_train_acc[cor_ind, severity_ind, ts_ind] = train_acc
            
            # evaluate the adapted model on the, corrupted val data, and reference (soure) data
            with torch.no_grad():
                crpt_val_correct, crpt_val_samples, ref_correct, ref_samples = 0, 0, 0, 0
                for images, labels in corrupted_dataloaders[cor_ind]['val']:
                    labels = labels.to(device)
                    outputs = model(images.to(device))
                    _, predicted = torch.max(outputs.data, 1)
                    crpt_val_correct += (predicted == labels).sum().item()
                    crpt_val_samples += len(labels)
                print(f"Corrupt Val Accuracy: {crpt_val_correct:#5.0f}/{crpt_val_samples:#5.0f} ({crpt_val_correct / crpt_val_samples})")
                rpl_corrupt_val_acc[cor_ind, severity_ind, ts_ind] = crpt_val_correct / crpt_val_samples

                for images, labels in ref_dataloaders['val']:
                    labels = labels.to(device)
                    outputs = model(images.to(device))
                    _, predicted = torch.max(outputs.data, 1)
                    ref_correct += (predicted == labels).sum().item()
                    ref_samples += len(labels)
                print(f"Ref Accuracy: {ref_correct:#5.0f}/{ref_samples:#5.0f} ({ref_correct / ref_samples})")
                rpl_ref_acc[cor_ind, severity_ind, ts_ind] = ref_correct / ref_samples


#         with open('RPL_corrupt_train_acc.npy', 'wb') as f:
#             np.save(f, rpl_corrupt_train_acc)
#         with open('RPL_corrupt_validation_acc.npy', 'wb') as f:
#             np.save(f, rpl_corrupt_val_acc)
#         with open('RPL_target_acc.npy', 'wb') as f:
#             np.save(f, rpl_ref_acc)
#         with open('RPL_adapt_time.npy', 'wb') as f:
#             np.save(f, rpl_adpt_times)
# Out:
# ## Experiment: Severity = 1, target_size = 32, corruption = zoom_blur
#         -0.1527, -0.0435, -0.0647, -0.1073, -0.0526, -0.1353, -0.0369, -0.0871,
#         -0.1052, -0.0962, -0.0830, -0.0958, -0.1381, -0.1304, -0.1635, -0.0761,
#         -0.1604, -0.1647, -0.0862, -0.0475, -0.0939, -0.0177,  0.0052, -0.0782,
#         -0.0853, -0.1527, -0.1343, -0.0596, -0.0928, -0.0101, -0.1562, -0.0552,
#         -0.1349, -0.0759, -0.1072, -0.1393, -0.0420, -0.0753, -0.1155, -0.1234,
#         -0.0285, -0.0537, -0.0836, -0.1072, -0.0658, -0.0532, -0.0873, -0.0196,
#         -0.1089, -0.1421, -0.0507, -0.1392, -0.0786, -0.0574, -0.0655, -0.0983,
#         -0.0884, -0.0519, -0.1583, -0.0888, -0.0605, -0.1102, -0.0423, -0.2398,
#         -0.0946, -0.1050, -0.1497, -0.1554, -0.0866, -0.0523, -0.0367, -0.0472,
#         -0.0806, -0.1023, -0.0720, -0.0919, -0.0608, -0.0726, -0.0944, -0.0921,
#         -0.1204, -0.1080, -0.0754, -0.0328, -0.1287, -0.1507, -0.0551, -0.1440,
#         -0.0325, -0.1261, -0.0513, -0.0846, -0.0517, -0.0326, -0.0307, -0.0716,
#         -0.1573, -0.0661, -0.1197, -0.1163, -0.0377, -0.1092, -0.0856, -0.0732,
#         -0.0665, -0.1104, -0.1927, -0.1020, -0.0255, -0.0175, -0.0949, -0.1281,
#         -0.0340, -0.0502, -0.0412, -0.0557, -0.1011, -0.0473, -0.1062, -0.1063,
#         -0.0897, -0.1047, -0.1253, -0.1090,  0.0092, -0.0317, -0.1205, -0.0663,
#         -0.2939, -0.1074, -0.0772, -0.0850, -0.1148, -0.1265, -0.0564, -0.1030,
#         -0.1038, -0.1395, -0.0805, -0.0830, -0.0490, -0.0906, -0.0434, -0.1156],
#        device='cuda:0', requires_grad=True), Parameter containing:
# tensor([0.6431, 0.8315, 0.7858,  ..., 0.5616, 0.7822, 0.5634], device='cuda:0',
#        requires_grad=True), Parameter containing:
# tensor([0.0084, 0.0549, 0.0348,  ..., 0.0219, 0.0207, 0.0076], device='cuda:0',
#        requires_grad=True)]
# Correct:   16./  32. (50.00 %)
# Adaptation time: 4.136745929718018
# Corrupt Val Accuracy:  611./ 992. (0.6159274193548387)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25696/2241030265.py in <module>
#      35                 rpl_corrupt_val_acc[cor_ind, severity_ind, ts_ind] = crpt_val_correct / crpt_val_samples
#      36
# ---> 37                 for images, labels in ref_dataloaders['val']:
#      38                     labels = labels.to(device)
#      39                     outputs = model(images.to(device))
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1194                 # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1195                 if not self._persistent_workers:
# -> 1196                     self._shutdown_workers()
#    1197                 raise StopIteration
#    1198
#
# ~/bin/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _shutdown_workers(self)
#    1323                 for q in self._index_queues:
#    1324                     q.cancel_join_thread()
# -> 1325                     q.close()
#    1326             finally:
#    1327                 # Even though all this function does is putting into queues that
#
# ~/bin/anaconda3/lib/python3.9/multiprocessing/queues.py in close(self)
#     146             if close:
#     147                 self._close = None
# --> 148                 close()
#     149
#     150     def join_thread(self):
#
# ~/bin/anaconda3/lib/python3.9/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     222                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223                           self._callback, self._args, self._kwargs)
# --> 224                 res = self._callback(*self._args, **self._kwargs)
#     225             self._weakref = self._callback = self._args = \
#     226                             self._kwargs = self._key = None
#
# ~/bin/anaconda3/lib/python3.9/multiprocessing/queues.py in _finalize_close(buffer, notempty)
#     208         debug('telling queue thread to quit')
#     209         with notempty:
# --> 210             buffer.append(_sentinel)
#     211             notempty.notify()
#     212
#
# KeyboardInterrupt:

# %%
with open('RPL_corrupt_train_acc.npy', 'wb') as f:
    np.save(f, rpl_corrupt_train_acc)
with open('RPL_corrupt_validation_acc.npy', 'wb') as f:
    np.save(f, rpl_corrupt_val_acc)
with open('RPL_target_acc.npy', 'wb') as f:
    np.save(f, rpl_ref_acc)
with open('RPL_adapt_time.npy', 'wb') as f:
    np.save(f, rpl_adpt_times)

# %%
with open('RPL_corrupt_train_acc.npy', 'rb') as f:
    rpl_corrupt_train_acc = np.load(f)
with open('RPL_corrupt_validation_acc.npy', 'rb') as f:
    rpl_corrupt_val_acc = np.load(f)
with open('RPL_target_acc.npy', 'rb') as f:
    rpl_ref_acc = np.load(f)
with open('RPL_adapt_time.npy', 'rb') as f:
    rpl_adpt_times = np.load(f)

# %%
rpl_corrupt_val_acc
# Out:
# array([[[0.5796371 , 0.61995968, 0.60887097, 0.61391129, 0.59375   ,
#          0.59879032],
#         [0.55645161, 0.51814516, 0.51814516, 0.51512097, 0.5453629 ,
#          0.54435484],
#         [0.46270161, 0.49697581, 0.4828629 , 0.49092742, 0.46774194,
#          0.50100806],
#         [0.45362903, 0.4375    , 0.45262097, 0.42842742, 0.41532258,
#          0.4233871 ],
#         [0.39314516, 0.40120968, 0.39314516, 0.39012097, 0.38407258,
#          0.39415323]],
#
#        [[0.61995968, 0.65625   , 0.65221774, 0.64818548, 0.64616935,
#          0.65020161],
#         [0.58971774, 0.61592742, 0.58971774, 0.59879032, 0.58064516,
#          0.60685484],
#         [0.44657258, 0.44657258, 0.42741935, 0.45967742, 0.45665323,
#          0.45060484],
#         [0.39112903, 0.38407258, 0.40120968, 0.39919355, 0.36491935,
#          0.38004032],
#         [0.28225806, 0.25504032, 0.3125    , 0.2983871 , 0.29939516,
#          0.30241935]],
#
#        [[0.72983871, 0.69455645, 0.69657258, 0.72379032, 0.72580645,
#          0.72177419],
#         [0.65625   , 0.64616935, 0.65221774, 0.66229839, 0.65725806,
#          0.63608871],
#         [0.58366935, 0.57056452, 0.5625    , 0.56653226, 0.58870968,
#          0.5796371 ],
#         [0.47782258, 0.53326613, 0.49899194, 0.4858871 , 0.50705645,
#          0.55040323],
#         [0.36290323, 0.33870968, 0.35383065, 0.37399194, 0.39012097,
#          0.40423387],
#         [0.24798387, 0.24495968, 0.22983871, 0.2328629 , 0.26310484,
#          0.30241935],
#         [0.15020161, 0.13709677, 0.15524194, 0.14717742, 0.18447581,
#          0.16028226]]])

# %%
rpl_corrupt_train_acc
# Out:
# array([[[0.1875    , 0.421875  , 0.3984375 , 0.41796875, 0.41601562,
#          0.40927419],
#         [0.3125    , 0.46875   , 0.3125    , 0.30078125, 0.34179688,
#          0.34274194],
#         [0.34375   , 0.28125   , 0.2734375 , 0.32421875, 0.27734375,
#          0.29334676],
#         [0.15625   , 0.15625   , 0.265625  , 0.265625  , 0.23242188,
#          0.20967741],
#         [0.28125   , 0.171875  , 0.1875    , 0.2109375 , 0.19335938,
#          0.22177419]],
#
#        [[0.53125   , 0.453125  , 0.4921875 , 0.4609375 , 0.50195312,
#          0.50604838],
#         [0.5625    , 0.4375    , 0.40625   , 0.3984375 , 0.50585938,
#          0.4576613 ],
#         [0.40625   , 0.3125    , 0.2890625 , 0.23046875, 0.29882812,
#          0.30846775],
#         [0.15625   , 0.140625  , 0.1796875 , 0.18359375, 0.1953125 ,
#          0.22681452],
#         [0.15625   , 0.125     , 0.1953125 , 0.15234375, 0.18554688,
#          0.15524194]],
#
#        [[0.71875   , 0.640625  , 0.640625  , 0.66015625, 0.60742188,
#          0.64415324],
#         [0.53125   , 0.484375  , 0.484375  , 0.546875  , 0.5078125 ,
#          0.48286289],
#         [0.34375   , 0.328125  , 0.328125  , 0.40234375, 0.390625  ,
#          0.44758064],
#         [0.3125    , 0.359375  , 0.2734375 , 0.37890625, 0.35546875,
#          0.32258064],
#         [0.375     , 0.171875  , 0.2109375 , 0.2578125 , 0.27539062,
#          0.25604838]],
#
#        [[0.5625    , 0.46875   , 0.40625   , 0.46484375, 0.45898438,
#          0.44959676],
#         [0.46875   , 0.234375  , 0.2890625 , 0.27734375, 0.32421875,
#          0.29435483],
#         [0.34375   , 0.28125   , 0.3125    , 0.25390625, 0.31445312,
#          0.29133064],
#         [0.1875    , 0.1875    , 0.1484375 , 0.1796875 , 0.21679688,
#          0.21169356],
#         [0.1875    , 0.25      , 0.1875    , 0.1796875 , 0.16601562,
#          0.19153225]],
#
#        [[0.65625   , 0.375     , 0.4296875 , 0.4140625 , 0.49023438,
#          0.48790324],
#         [0.3125    , 0.328125  , 0.3671875 , 0.328125  , 0.31445312,
#          0.38104838],
#         [0.125     , 0.125     , 0.15625   , 0.16015625, 0.16992188,
#          0.20262097],
#         [0.09375   , 0.0625    , 0.0859375 , 0.1171875 , 0.10546875,
#          0.15221775],
#         [0.03125   , 0.09375   , 0.0546875 , 0.08203125, 0.07226562,
#          0.09072581]],
#
#        [[0.5625    , 0.484375  , 0.5234375 , 0.4765625 , 0.47851562,
#          0.5090726 ],
#         [0.34375   , 0.3125    , 0.3515625 , 0.390625  , 0.42773438,
#          0.38508064],
#         [0.25      , 0.234375  , 0.25      , 0.25      , 0.31054688,
#         [0.        , 0.03125   , 0.0078125 , 0.02734375, 0.04492188,
#          0.05947581]],
#
#        [[0.5       , 0.515625  , 0.53125   , 0.59375   , 0.53710938,
#          0.56754035],
#         [0.25      , 0.359375  , 0.3984375 , 0.39453125, 0.41992188,
#          0.40221775],
#         [0.4375    , 0.4375    , 0.5234375 , 0.5       , 0.48632812,
#          0.52520162],
#         [0.46875   , 0.328125  , 0.3515625 , 0.42578125, 0.42382812,
#          0.46572581],
#         [0.28125   , 0.234375  , 0.234375  , 0.3046875 , 0.31445312,
#          0.30342743]],
#
#        [[0.71875   , 0.578125  , 0.6015625 , 0.61328125, 0.5859375 ,
#          0.59375   ],
#         [0.625     , 0.46875   , 0.5234375 , 0.546875  , 0.5859375 ,
#          0.56350809],
#         [0.5625    , 0.484375  , 0.453125  , 0.46875   , 0.47460938,
#          0.51310486],
#         [0.34375   , 0.390625  , 0.40625   , 0.37890625, 0.40234375,
#          0.38508064],
#         [0.21875   , 0.28125   , 0.203125  , 0.26953125, 0.30078125,
#          0.28931451]],
#
#        [[0.65625   , 0.421875  , 0.515625  , 0.5078125 , 0.56640625,
#          0.56350809],
#         [0.40625   , 0.5       , 0.3984375 , 0.45703125, 0.50976562,
#          0.52318549],
#         [0.34375   , 0.375     , 0.4609375 , 0.34765625, 0.45703125,
#          0.46673387],
#         [0.34375   , 0.265625  , 0.3203125 , 0.31640625, 0.36328125,
#          0.3639113 ],
#         [0.09375   , 0.1875    , 0.2421875 , 0.21484375, 0.18554688,
#          0.24395162]],
#
#        [[0.375     , 0.390625  , 0.3515625 , 0.3828125 , 0.45507812,
#          0.46471775],
#         [0.34375   , 0.3125    , 0.34375   , 0.296875  , 0.33203125,
#          0.37298387],
#         [0.125     , 0.25      , 0.1484375 , 0.23046875, 0.234375  ,
#          0.2610887 ],
#         [0.1875    , 0.0625    , 0.125     , 0.12109375, 0.1328125 ,
#          0.17943548],
#         [0.03125   , 0.03125   , 0.046875  , 0.1015625 , 0.09960938,
#          0.1078629 ]]])

# %% [markdown]
# ## Comparison with TENT

# %%
# validation accuracy averaged over all corruptions and all batch sizes
# sev1, 2, 3, 4, 5
rpl_corrupt_val_acc.transpose(2, 1, 0).mean(axis=0).mean(axis=1)
# Out:
# array([0.67395413, 0.59870632, 0.53384367, 0.45141339, 0.35242356])

# %%
# validation accuracy (batch size = 32) averaged over all corruptions
# sev1, 2, 3, 4, 5
rpl_corrupt_val_acc.transpose(2, 1, 0)[0].mean(axis=1)
# Out:
# array([0.67149698, 0.59450605, 0.52948589, 0.44449345, 0.34923135])

# %%
# validation error rate averaged over all corruptions and all batch sizes, shuffled
# sev5, 4, 3, 2, 1
(1 - rpl_corrupt_val_acc.transpose(2, 1, 0).mean(axis=0).mean(axis=1))[::-1]
# Out:
# array([0.64757644, 0.54858661, 0.46615633, 0.40129368, 0.32604587])

# %%
# validation error rate (batch size = 32) averaged over all corruptions, shuffled
# sev5, 4, 3, 2, 1
1 - rpl_corrupt_val_acc.transpose(2, 1, 0)[0].mean(axis=1)[::-1]
# Out:
# array([0.65076865, 0.55550655, 0.47051411, 0.40549395, 0.32850302])

# %% [markdown]
# ## Comparison with RPL Paper

# %%
print(corruption)
1-rpl_corrupt_val_acc.mean(axis=1).mean(axis=1)
# Out:
# ['zoom_blur', 'speckle_noise', 'spatter', 'snow', 'glass_blur', 'motion_blur', 'saturate', 'gaussian_blur', 'frost', 'fog', 'brightness', 'contrast', 'elastic_transform', 'pixelate', 'jpeg_compression', 'defocus_blur']
# array([0.51061828, 0.52624328, 0.43222446, 0.55090726, 0.62846102,
#        0.52211022, 0.32402554, 0.58397177, 0.54868952, 0.40268817,
#        0.30131048, 0.47086694, 0.42217742, 0.3905914 , 0.41875   ,
#        0.61327285])

# %%
1 - baseline_performances.mean(axis=1).mean(axis=1)
# Out:
# array([0.63765941, 0.63858019, 0.50879715, 0.67556213, 0.73131435,
#        0.61035379, 0.38323564, 0.58333158, 0.6227243 , 0.54395559,
#        0.31226967, 0.61064041, 0.55121667, 0.55014742, 0.46622676,
#        0.61470044])

# %% [markdown]
# # One-shot adaptation

# %%
import time

# %%
def few_shot_adapt(
#         datadir = '/data/imagenetc/gaussian_blur/3',
        model,
        dataloader,
        num_epochs = 1, # followed their findings in the paper
        batch_size = 32,
        learning_rate = 0.75e-3,
        gce_q = 0.8,
    ):
    
#     model = models.resnet50(pretrained = True).to(device)
    parameters = adapt_batchnorm(model)
#     # TODO change this loader
#     val_loader = get_dataset_loader(
#         datadir,
#         batch_size = batch_size,
#         shuffle = True
#     )
    optimizer = torch.optim.SGD(
        model.parameters(), lr = learning_rate
    )
    
    num_correct, num_samples = 0., 0.
    for epoch in range(num_epochs):
        predictions = []
#         batch_inf_times = []
        batch_accs = []
#         step = 0
        for images, labels in dataloader:
#             start = time.time()
#             print(f"DEBUGGING: num_samples = {num_samples}")
            outputs = model(images.to(device))
            predictions = outputs.argmax(dim = 1)
#             _, predicted = torch.max(outputs.data, 1)

#             inference_time = time.time() - start
#             batch_inf_times.append(inference_time)

#             batch_accuracy = ((predicted == labels).sum().item()) / labels.size(0)
#             batch_accs.append(batch_accuracy)

            # TODO: in our scenario, do we want to revert back to original model after adapting in each step?
            loss = gce(outputs, predictions, q = gce_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            outputs = model(images.to(device))
            predictions = outputs.argmax(dim = 1)

            num_correct += (predictions.detach().cpu() == labels).float().sum()
            num_samples += len(labels)
#                 print(f"DEBUGGING: len(labels) = {len(labels)}")

#                 step += 1
#                 print(f"Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
    
    print(f"Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
    return num_correct/num_samples

# %%
target_sizes = [32, 64, 128, 256, 512, 1000]
severity = [1,2,3,4,5]

rpl_one_shot_acc = np.zeros(shape=(len(corruption), len(severity)))
# rpl_corrupt_val_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))
# rpl_ref_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))


# rpl_one_shot_adpt_times = np.zeros(shape=(len(corruption), len(severity)))
device
# Out:
# device(type='cuda')

# %%
# test on 1000 datapoints within
for severity_ind in range(len(severity)):
    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, severity[severity_ind], 1, 1000)


    # adapt the model using the rpl methods
    # evaluate the adapted model on the test corrupted (target) dataset & the reference (source) dataset
    for cor_ind in range(len(corrupted_dataloaders)):
        print(f'## Experiment: Severity = {severity[severity_ind]}, corruption = {corruption[cor_ind]}, shot_size = {1}')
#         one_shot_accs = []
        
        model = models.resnet50(pretrained=True)
        model.to(device)


            # adapt the model
    #         start = time.time()
        training_acc = few_shot_adapt(model, corrupted_dataloaders[cor_ind]['train'])
    #         adapt_time = time.time() - start
    #         print(f"Adaptation time: {adapt_time}")
        print('Few_shot_accuracies are:', training_acc)

#         rpl_one_shot_adpt_times[cor_ind, severity_ind] = one_shot_accs.mean()
        rpl_one_shot_acc[cor_ind, severity_ind] = training_acc


    with open('rpl_one_shot_acc.npy', 'wb') as f:
        np.save(f, rpl_one_shot_acc)
#         with open('RPL_corrupt_validation_acc.npy', 'wb') as f:
#             np.save(f, rpl_corrupt_val_acc)
#         with open('RPL_target_acc.npy', 'wb') as f:
#             np.save(f, rpl_ref_acc)
#     with open('rpl_one_shot_adpt_times.npy', 'wb') as f:
#         np.save(f, rpl_one_shot_adpt_times)
# Out:
# ## Experiment: Severity = 1, corruption = zoom_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = speckle_noise
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = spatter
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 1, corruption = snow
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 1, corruption = glass_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = motion_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = saturate
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 1, corruption = gaussian_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = frost
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = fog
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 1, corruption = brightness
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = contrast
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = elastic_transform
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = pixelate
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 1, corruption = jpeg_compression
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 1, corruption = defocus_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = zoom_blur
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 2, corruption = speckle_noise
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = spatter
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = snow
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 2, corruption = glass_blur
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: tensor(0.0030)
# ## Experiment: Severity = 2, corruption = motion_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = saturate
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 2, corruption = gaussian_blur
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 2, corruption = frost
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 2, corruption = fog
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 2, corruption = brightness
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 2, corruption = contrast
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = elastic_transform
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = pixelate
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: tensor(0.0030)
# ## Experiment: Severity = 2, corruption = jpeg_compression
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 2, corruption = defocus_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = zoom_blur
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 3, corruption = speckle_noise
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 3, corruption = spatter
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 3, corruption = snow
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = glass_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = motion_blur
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 3, corruption = saturate
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 3, corruption = gaussian_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = frost
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = fog
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 3, corruption = brightness
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = contrast
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 3, corruption = elastic_transform
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = pixelate
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 3, corruption = jpeg_compression
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 3, corruption = defocus_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = zoom_blur
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 4, corruption = speckle_noise
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 4, corruption = spatter
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = snow
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 4, corruption = glass_blur
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 4, corruption = motion_blur
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 4, corruption = saturate
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = gaussian_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = frost
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = fog
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 4, corruption = brightness
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 4, corruption = contrast
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = elastic_transform
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = pixelate
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = jpeg_compression
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 4, corruption = defocus_blur
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = zoom_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 5, corruption = speckle_noise
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = spatter
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = snow
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 5, corruption = glass_blur
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: tensor(0.0030)
# ## Experiment: Severity = 5, corruption = motion_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 5, corruption = saturate
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = gaussian_blur
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = frost
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = fog
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)
# ## Experiment: Severity = 5, corruption = brightness
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: tensor(0.0010)
# ## Experiment: Severity = 5, corruption = contrast
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 5, corruption = elastic_transform
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: tensor(0.0030)
# ## Experiment: Severity = 5, corruption = pixelate
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 5, corruption = jpeg_compression
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: tensor(0.0020)
# ## Experiment: Severity = 5, corruption = defocus_blur
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: tensor(0.)

# %%
rpl_one_shot_acc
# Out:
# array([[0.   , 0.002, 0.002, 0.002, 0.   ],
#        [0.   , 0.   , 0.001, 0.001, 0.001],
#        [0.002, 0.   , 0.001, 0.   , 0.001],
#        [0.002, 0.002, 0.   , 0.002, 0.   ],
#        [0.   , 0.003, 0.   , 0.001, 0.003],
#        [0.   , 0.   , 0.002, 0.002, 0.   ],
#        [0.002, 0.001, 0.002, 0.   , 0.001],
#        [0.   , 0.001, 0.   , 0.   , 0.001],
#        [0.   , 0.002, 0.   , 0.   , 0.001],
#        [0.001, 0.001, 0.001, 0.001, 0.   ],
#        [0.   , 0.001, 0.   , 0.002, 0.001],
#        [0.   , 0.   , 0.002, 0.   , 0.002],
#        [0.   , 0.   , 0.   , 0.   , 0.003],
#        [0.   , 0.003, 0.   , 0.   , 0.002],
#        [0.001, 0.   , 0.001, 0.   , 0.002],
#        [0.   , 0.   , 0.   , 0.001, 0.   ]])

# %%
# repeat same step 32 times outside
for severity_ind in range(len(severity)):
    ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
    = get_imagenetc(imagebase, severity[severity_ind], 1, 1)


    # adapt the model using the rpl methods
    # evaluate the adapted model on the test corrupted (target) dataset & the reference (source) dataset
    for cor_ind in range(len(corrupted_dataloaders)):
        print(f'## Experiment: Severity = {severity[severity_ind]}, corruption = {corruption[cor_ind]}')
        one_shot_accs = []
        
        for i in range(32):
            model = models.resnet50(pretrained=True)
            model.to(device)


            # adapt the model
    #         start = time.time()
            one_shot_accs.append(one_shot_adapt(model, corrupted_dataloaders[cor_ind]['train']))
    #         adapt_time = time.time() - start
    #         print(f"Adaptation time: {adapt_time}")
        print('One_shot_accuracies are:', one_shot_accs)

#         rpl_one_shot_adpt_times[cor_ind, severity_ind] = one_shot_accs.mean()
        rpl_one_shot_acc[cor_ind, severity_ind] = np.mean(one_shot_accs)


    with open('rpl_one_shot_acc.npy', 'wb') as f:
        np.save(f, rpl_one_shot_acc)
#         with open('RPL_corrupt_validation_acc.npy', 'wb') as f:
#             np.save(f, rpl_corrupt_val_acc)
#         with open('RPL_target_acc.npy', 'wb') as f:
#             np.save(f, rpl_ref_acc)
#     with open('rpl_one_shot_adpt_times.npy', 'wb') as f:
#         np.save(f, rpl_one_shot_adpt_times)

# %% [markdown]
# # Few-shot adaptation

# %%
import time

# %%
def few_shot_adapt(
#         datadir = '/data/imagenetc/gaussian_blur/3',
        model,
        dataloader,
        num_epochs = 1, # followed their findings in the paper
        batch_size = 32,
        learning_rate = 0.75e-3,
        gce_q = 0.8,
    ):
    
#     model = models.resnet50(pretrained = True).to(device)
    parameters = adapt_batchnorm(model)
#     # TODO change this loader
#     val_loader = get_dataset_loader(
#         datadir,
#         batch_size = batch_size,
#         shuffle = True
#     )
    optimizer = torch.optim.SGD(
        model.parameters(), lr = learning_rate
    )
    
    num_correct, num_samples = 0., 0.
    for epoch in range(num_epochs):
        predictions = []
#         batch_inf_times = []
        batch_accs = []
#         step = 0
        for images, labels in dataloader:
#             start = time.time()
#             print(f"DEBUGGING: num_samples = {num_samples}")
            outputs = model(images.to(device))
            predictions = outputs.argmax(dim = 1)
#             _, predicted = torch.max(outputs.data, 1)

#             inference_time = time.time() - start
#             batch_inf_times.append(inference_time)

#             batch_accuracy = ((predicted == labels).sum().item()) / labels.size(0)
#             batch_accs.append(batch_accuracy)

            # TODO: in our scenario, do we want to revert back to original model after adapting in each step?
            loss = gce(outputs, predictions, q = gce_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            outputs = model(images.to(device))
            predictions = outputs.argmax(dim = 1)

            num_correct += (predictions.detach().cpu() == labels).float().sum()
            num_samples += len(labels)
#                 print(f"DEBUGGING: len(labels) = {len(labels)}")

#                 step += 1
#                 print(f"Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
    
    print(f"Correct: {num_correct:#5.0f}/{num_samples:#5.0f} ({100 * num_correct / num_samples:.2f} %)")
    return num_correct/num_samples

# %%
shot_sizes = [1, 5, 10, 15, 20, 25, 30, 32]
severity = [1,2,3,4,5]

rpl_few_shot_acc = np.zeros(shape=(len(corruption), len(severity), len(shot_sizes)))
# rpl_corrupt_val_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))
# rpl_ref_acc = np.zeros(shape=(len(corruption), len(severity), len(target_sizes)))


# rpl_one_shot_adpt_times = np.zeros(shape=(len(corruption), len(severity)))
device
rpl_few_shot_acc.shape
# Out:
# (16, 5, 8)

# %%
# test on 1000 datapoints within
for severity_ind in range(len(severity)):
    for ss_ind in range(len(shot_sizes)):
        ref_dataloaders, ref_dataset_sizes, corrupted_dataloaders, corrupted_dataset_sizes, corruption \
        = get_imagenetc(imagebase, severity[severity_ind], shot_sizes[ss_ind], 1000)


        # adapt the model using the rpl methods
        # evaluate the adapted model on the test corrupted (target) dataset & the reference (source) dataset
        for cor_ind in range(len(corrupted_dataloaders)):
            print(f'## Experiment: Severity = {severity[severity_ind]}, corruption = {corruption[cor_ind]}, shot_size = {shot_sizes[ss_ind]}')
    #         one_shot_accs = []

            model = models.resnet50(pretrained=True)
            model.to(device)


                # adapt the model
        #         start = time.time()
            training_acc = few_shot_adapt(model, corrupted_dataloaders[cor_ind]['train']).numpy()
        #         adapt_time = time.time() - start
        #         print(f"Adaptation time: {adapt_time}")
            print('One_shot_accuracies are:', training_acc)

    #         rpl_one_shot_adpt_times[cor_ind, severity_ind] = one_shot_accs.mean()
            rpl_few_shot_acc[cor_ind, severity_ind, ss_ind] = training_acc


        with open('rpl_few_shot_acc.npy', 'wb') as f:
            np.save(f, rpl_few_shot_acc)
    #         with open('RPL_corrupt_validation_acc.npy', 'wb') as f:
    #             np.save(f, rpl_corrupt_val_acc)
    #         with open('RPL_target_acc.npy', 'wb') as f:
    #             np.save(f, rpl_ref_acc)
    #     with open('rpl_one_shot_adpt_times.npy', 'wb') as f:
    #         np.save(f, rpl_one_shot_adpt_times)
# Out:
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = snow, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = frost, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = fog, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 1
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: 0.003
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 5
# Correct:  315./1000. (31.50 %)
# One_shot_accuracies are: 0.315
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 5
# Correct:  388./1000. (38.80 %)
# One_shot_accuracies are: 0.388
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 5
# Correct:  467./1000. (46.70 %)
# One_shot_accuracies are: 0.467
# ## Experiment: Severity = 1, corruption = snow, shot_size = 5
# Correct:  335./1000. (33.50 %)
# One_shot_accuracies are: 0.335
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 5
# Correct:  326./1000. (32.60 %)
# One_shot_accuracies are: 0.326
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 5
# Correct:  379./1000. (37.90 %)
# One_shot_accuracies are: 0.379
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 5
# Correct:  438./1000. (43.80 %)
# One_shot_accuracies are: 0.438
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 5
# Correct:  400./1000. (40.00 %)
# One_shot_accuracies are: 0.4
# ## Experiment: Severity = 1, corruption = frost, shot_size = 5
# Correct:  355./1000. (35.50 %)
# One_shot_accuracies are: 0.355
# ## Experiment: Severity = 1, corruption = fog, shot_size = 5
# Correct:  405./1000. (40.50 %)
# One_shot_accuracies are: 0.405
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 5
# Correct:  462./1000. (46.20 %)
# One_shot_accuracies are: 0.462
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 5
# Correct:  387./1000. (38.70 %)
# One_shot_accuracies are: 0.387
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 5
# Correct:  421./1000. (42.10 %)
# One_shot_accuracies are: 0.421
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 5
# Correct:  439./1000. (43.90 %)
# One_shot_accuracies are: 0.439
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 5
# Correct:  365./1000. (36.50 %)
# One_shot_accuracies are: 0.365
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 5
# Correct:  290./1000. (29.00 %)
# One_shot_accuracies are: 0.29
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 10
# Correct:  389./1000. (38.90 %)
# One_shot_accuracies are: 0.389
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 10
# Correct:  440./1000. (44.00 %)
# One_shot_accuracies are: 0.44
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 10
# Correct:  556./1000. (55.60 %)
# One_shot_accuracies are: 0.556
# ## Experiment: Severity = 1, corruption = snow, shot_size = 10
# Correct:  377./1000. (37.70 %)
# One_shot_accuracies are: 0.377
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 10
# Correct:  391./1000. (39.10 %)
# One_shot_accuracies are: 0.391
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 10
# Correct:  434./1000. (43.40 %)
# One_shot_accuracies are: 0.434
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 10
# Correct:  530./1000. (53.00 %)
# One_shot_accuracies are: 0.53
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 10
# Correct:  440./1000. (44.00 %)
# One_shot_accuracies are: 0.44
# ## Experiment: Severity = 1, corruption = frost, shot_size = 10
# Correct:  438./1000. (43.80 %)
# One_shot_accuracies are: 0.438
# ## Experiment: Severity = 1, corruption = fog, shot_size = 10
# Correct:  444./1000. (44.40 %)
# One_shot_accuracies are: 0.444
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 10
# Correct:  555./1000. (55.50 %)
# One_shot_accuracies are: 0.555
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 10
# Correct:  474./1000. (47.40 %)
# One_shot_accuracies are: 0.474
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 10
# Correct:  489./1000. (48.90 %)
# One_shot_accuracies are: 0.489
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 10
# Correct:  508./1000. (50.80 %)
# One_shot_accuracies are: 0.508
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 10
# Correct:  457./1000. (45.70 %)
# One_shot_accuracies are: 0.457
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 10
# Correct:  359./1000. (35.90 %)
# One_shot_accuracies are: 0.359
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 15
# Correct:  389./ 990. (39.29 %)
# One_shot_accuracies are: 0.3929293
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 15
# Correct:  468./ 990. (47.27 %)
# One_shot_accuracies are: 0.47272727
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 15
# Correct:  547./ 990. (55.25 %)
# One_shot_accuracies are: 0.5525253
# ## Experiment: Severity = 1, corruption = snow, shot_size = 15
# Correct:  390./ 990. (39.39 %)
# One_shot_accuracies are: 0.3939394
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 15
# Correct:  390./ 990. (39.39 %)
# One_shot_accuracies are: 0.3939394
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 15
# Correct:  433./ 990. (43.74 %)
# One_shot_accuracies are: 0.43737373
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 15
# Correct:  574./ 990. (57.98 %)
# One_shot_accuracies are: 0.579798
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 15
# Correct:  468./ 990. (47.27 %)
# One_shot_accuracies are: 0.47272727
# ## Experiment: Severity = 1, corruption = frost, shot_size = 15
# Correct:  453./ 990. (45.76 %)
# One_shot_accuracies are: 0.45757577
# ## Experiment: Severity = 1, corruption = fog, shot_size = 15
# Correct:  453./ 990. (45.76 %)
# One_shot_accuracies are: 0.45757577
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 15
# Correct:  556./ 990. (56.16 %)
# One_shot_accuracies are: 0.5616162
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 15
# Correct:  493./ 990. (49.80 %)
# One_shot_accuracies are: 0.4979798
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 15
# Correct:  490./ 990. (49.49 %)
# One_shot_accuracies are: 0.4949495
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 15
# Correct:  535./ 990. (54.04 %)
# One_shot_accuracies are: 0.540404
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 15
# Correct:  480./ 990. (48.48 %)
# One_shot_accuracies are: 0.4848485
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 15
# Correct:  395./ 990. (39.90 %)
# One_shot_accuracies are: 0.3989899
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 20
# Correct:  390./1000. (39.00 %)
# One_shot_accuracies are: 0.39
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 20
# Correct:  486./1000. (48.60 %)
# One_shot_accuracies are: 0.486
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 20
# Correct:  585./1000. (58.50 %)
# One_shot_accuracies are: 0.585
# ## Experiment: Severity = 1, corruption = snow, shot_size = 20
# Correct:  427./1000. (42.70 %)
# One_shot_accuracies are: 0.427
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 20
# Correct:  404./1000. (40.40 %)
# One_shot_accuracies are: 0.404
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 20
# Correct:  460./1000. (46.00 %)
# One_shot_accuracies are: 0.46
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 20
# Correct:  558./1000. (55.80 %)
# One_shot_accuracies are: 0.558
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 20
# Correct:  511./1000. (51.10 %)
# One_shot_accuracies are: 0.511
# ## Experiment: Severity = 1, corruption = frost, shot_size = 20
# Correct:  453./1000. (45.30 %)
# One_shot_accuracies are: 0.453
# ## Experiment: Severity = 1, corruption = fog, shot_size = 20
# Correct:  490./1000. (49.00 %)
# One_shot_accuracies are: 0.49
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 20
# Correct:  586./1000. (58.60 %)
# One_shot_accuracies are: 0.586
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 20
# Correct:  538./1000. (53.80 %)
# One_shot_accuracies are: 0.538
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 20
# Correct:  522./1000. (52.20 %)
# One_shot_accuracies are: 0.522
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 20
# Correct:  528./1000. (52.80 %)
# One_shot_accuracies are: 0.528
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 20
# Correct:  527./1000. (52.70 %)
# One_shot_accuracies are: 0.527
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 20
# Correct:  360./1000. (36.00 %)
# One_shot_accuracies are: 0.36
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 25
# Correct:  365./1000. (36.50 %)
# One_shot_accuracies are: 0.365
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 25
# Correct:  496./1000. (49.60 %)
# One_shot_accuracies are: 0.496
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 25
# Correct:  586./1000. (58.60 %)
# One_shot_accuracies are: 0.586
# ## Experiment: Severity = 1, corruption = snow, shot_size = 25
# Correct:  439./1000. (43.90 %)
# One_shot_accuracies are: 0.439
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 25
# Correct:  437./1000. (43.70 %)
# One_shot_accuracies are: 0.437
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 25
# Correct:  460./1000. (46.00 %)
# One_shot_accuracies are: 0.46
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 25
# Correct:  564./1000. (56.40 %)
# One_shot_accuracies are: 0.564
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 25
# Correct:  508./1000. (50.80 %)
# One_shot_accuracies are: 0.508
# ## Experiment: Severity = 1, corruption = frost, shot_size = 25
# Correct:  454./1000. (45.40 %)
# One_shot_accuracies are: 0.454
# ## Experiment: Severity = 1, corruption = fog, shot_size = 25
# Correct:  479./1000. (47.90 %)
# One_shot_accuracies are: 0.479
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 25
# Correct:  602./1000. (60.20 %)
# One_shot_accuracies are: 0.602
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 25
# Correct:  491./1000. (49.10 %)
# One_shot_accuracies are: 0.491
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 25
# Correct:  550./1000. (55.00 %)
# One_shot_accuracies are: 0.55
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 25
# Correct:  551./1000. (55.10 %)
# One_shot_accuracies are: 0.551
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 25
# Correct:  525./1000. (52.50 %)
# One_shot_accuracies are: 0.525
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 25
# Correct:  352./1000. (35.20 %)
# One_shot_accuracies are: 0.352
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 30
# Correct:  386./ 990. (38.99 %)
# One_shot_accuracies are: 0.389899
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 30
# Correct:  502./ 990. (50.71 %)
# One_shot_accuracies are: 0.5070707
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 30
# Correct:  569./ 990. (57.47 %)
# One_shot_accuracies are: 0.5747475
# ## Experiment: Severity = 1, corruption = snow, shot_size = 30
# Correct:  412./ 990. (41.62 %)
# One_shot_accuracies are: 0.41616163
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 30
# Correct:  441./ 990. (44.55 %)
# One_shot_accuracies are: 0.44545454
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 30
# Correct:  465./ 990. (46.97 %)
# One_shot_accuracies are: 0.46969697
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 30
# Correct:  585./ 990. (59.09 %)
# One_shot_accuracies are: 0.59090906
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 30
# Correct:  494./ 990. (49.90 %)
# One_shot_accuracies are: 0.4989899
# ## Experiment: Severity = 1, corruption = frost, shot_size = 30
# Correct:  430./ 990. (43.43 %)
# One_shot_accuracies are: 0.43434343
# ## Experiment: Severity = 1, corruption = fog, shot_size = 30
# Correct:  501./ 990. (50.61 %)
# One_shot_accuracies are: 0.5060606
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 30
# Correct:  598./ 990. (60.40 %)
# One_shot_accuracies are: 0.6040404
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 30
# Correct:  513./ 990. (51.82 %)
# One_shot_accuracies are: 0.5181818
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 30
# Correct:  529./ 990. (53.43 %)
# One_shot_accuracies are: 0.5343434
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 30
# Correct:  545./ 990. (55.05 %)
# One_shot_accuracies are: 0.55050504
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 30
# Correct:  483./ 990. (48.79 %)
# One_shot_accuracies are: 0.4878788
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 30
# Correct:  353./ 990. (35.66 %)
# One_shot_accuracies are: 0.35656565
# ## Experiment: Severity = 1, corruption = zoom_blur, shot_size = 32
# Correct:  376./ 992. (37.90 %)
# One_shot_accuracies are: 0.37903225
# ## Experiment: Severity = 1, corruption = speckle_noise, shot_size = 32
# Correct:  495./ 992. (49.90 %)
# One_shot_accuracies are: 0.49899194
# ## Experiment: Severity = 1, corruption = spatter, shot_size = 32
# Correct:  567./ 992. (57.16 %)
# One_shot_accuracies are: 0.5715726
# ## Experiment: Severity = 1, corruption = snow, shot_size = 32
# Correct:  403./ 992. (40.62 %)
# One_shot_accuracies are: 0.40625
# ## Experiment: Severity = 1, corruption = glass_blur, shot_size = 32
# Correct:  420./ 992. (42.34 %)
# One_shot_accuracies are: 0.4233871
# ## Experiment: Severity = 1, corruption = motion_blur, shot_size = 32
# Correct:  478./ 992. (48.19 %)
# One_shot_accuracies are: 0.48185483
# ## Experiment: Severity = 1, corruption = saturate, shot_size = 32
# Correct:  537./ 992. (54.13 %)
# One_shot_accuracies are: 0.54133064
# ## Experiment: Severity = 1, corruption = gaussian_blur, shot_size = 32
# Correct:  495./ 992. (49.90 %)
# One_shot_accuracies are: 0.49899194
# ## Experiment: Severity = 1, corruption = frost, shot_size = 32
# Correct:  454./ 992. (45.77 %)
# One_shot_accuracies are: 0.4576613
# ## Experiment: Severity = 1, corruption = fog, shot_size = 32
# Correct:  494./ 992. (49.80 %)
# One_shot_accuracies are: 0.49798387
# ## Experiment: Severity = 1, corruption = brightness, shot_size = 32
# Correct:  614./ 992. (61.90 %)
# One_shot_accuracies are: 0.6189516
# ## Experiment: Severity = 1, corruption = contrast, shot_size = 32
# Correct:  517./ 992. (52.12 %)
# One_shot_accuracies are: 0.52116936
# ## Experiment: Severity = 1, corruption = elastic_transform, shot_size = 32
# Correct:  527./ 992. (53.12 %)
# One_shot_accuracies are: 0.53125
# ## Experiment: Severity = 1, corruption = pixelate, shot_size = 32
# Correct:  550./ 992. (55.44 %)
# One_shot_accuracies are: 0.5544355
# ## Experiment: Severity = 1, corruption = jpeg_compression, shot_size = 32
# Correct:  488./ 992. (49.19 %)
# One_shot_accuracies are: 0.4919355
# ## Experiment: Severity = 1, corruption = defocus_blur, shot_size = 32
# Correct:  372./ 992. (37.50 %)
# One_shot_accuracies are: 0.375
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = snow, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 1
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: 0.003
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = frost, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 2, corruption = fog, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 5
# Correct:  241./1000. (24.10 %)
# One_shot_accuracies are: 0.241
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 5
# Correct:  328./1000. (32.80 %)
# One_shot_accuracies are: 0.328
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 5
# Correct:  377./1000. (37.70 %)
# One_shot_accuracies are: 0.377
# ## Experiment: Severity = 2, corruption = snow, shot_size = 5
# Correct:  202./1000. (20.20 %)
# One_shot_accuracies are: 0.202
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 5
# Correct:  219./1000. (21.90 %)
# One_shot_accuracies are: 0.219
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 5
# Correct:  269./1000. (26.90 %)
# One_shot_accuracies are: 0.269
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 5
# Correct:  411./1000. (41.10 %)
# One_shot_accuracies are: 0.411
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 5
# Correct:  257./1000. (25.70 %)
# One_shot_accuracies are: 0.257
# ## Experiment: Severity = 2, corruption = frost, shot_size = 5
# Correct:  233./1000. (23.30 %)
# One_shot_accuracies are: 0.233
# ## Experiment: Severity = 2, corruption = fog, shot_size = 5
# Correct:  321./1000. (32.10 %)
# One_shot_accuracies are: 0.321
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 5
# Correct:  444./1000. (44.40 %)
# One_shot_accuracies are: 0.444
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 5
# Correct:  350./1000. (35.00 %)
# One_shot_accuracies are: 0.35
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 5
# Correct:  266./1000. (26.60 %)
# One_shot_accuracies are: 0.266
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 5
# Correct:  438./1000. (43.80 %)
# One_shot_accuracies are: 0.438
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 5
# Correct:  325./1000. (32.50 %)
# One_shot_accuracies are: 0.325
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 5
# Correct:  205./1000. (20.50 %)
# One_shot_accuracies are: 0.205
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 10
# Correct:  308./1000. (30.80 %)
# One_shot_accuracies are: 0.308
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 10
# Correct:  391./1000. (39.10 %)
# One_shot_accuracies are: 0.391
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 10
# Correct:  446./1000. (44.60 %)
# One_shot_accuracies are: 0.446
# ## Experiment: Severity = 2, corruption = snow, shot_size = 10
# Correct:  274./1000. (27.40 %)
# One_shot_accuracies are: 0.274
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 10
# Correct:  273./1000. (27.30 %)
# One_shot_accuracies are: 0.273
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 10
# Correct:  362./1000. (36.20 %)
# One_shot_accuracies are: 0.362
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 10
# Correct:  499./1000. (49.90 %)
# One_shot_accuracies are: 0.499
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 10
# Correct:  309./1000. (30.90 %)
# One_shot_accuracies are: 0.309
# ## Experiment: Severity = 2, corruption = frost, shot_size = 10
# Correct:  303./1000. (30.30 %)
# One_shot_accuracies are: 0.303
# ## Experiment: Severity = 2, corruption = fog, shot_size = 10
# Correct:  392./1000. (39.20 %)
# One_shot_accuracies are: 0.392
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 10
# Correct:  557./1000. (55.70 %)
# One_shot_accuracies are: 0.557
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 10
# Correct:  411./1000. (41.10 %)
# One_shot_accuracies are: 0.411
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 10
# Correct:  320./1000. (32.00 %)
# One_shot_accuracies are: 0.32
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 10
# Correct:  504./1000. (50.40 %)
# One_shot_accuracies are: 0.504
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 10
# Correct:  414./1000. (41.40 %)
# One_shot_accuracies are: 0.414
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 10
# Correct:  259./1000. (25.90 %)
# One_shot_accuracies are: 0.259
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 15
# Correct:  309./ 990. (31.21 %)
# One_shot_accuracies are: 0.3121212
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 15
# Correct:  429./ 990. (43.33 %)
# One_shot_accuracies are: 0.43333334
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 15
# Correct:  446./ 990. (45.05 %)
# One_shot_accuracies are: 0.45050505
# ## Experiment: Severity = 2, corruption = snow, shot_size = 15
# Correct:  260./ 990. (26.26 %)
# One_shot_accuracies are: 0.26262626
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 15
# Correct:  319./ 990. (32.22 %)
# One_shot_accuracies are: 0.32222223
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 15
# Correct:  364./ 990. (36.77 %)
# One_shot_accuracies are: 0.36767676
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 15
# Correct:  507./ 990. (51.21 %)
# One_shot_accuracies are: 0.5121212
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 15
# Correct:  304./ 990. (30.71 %)
# One_shot_accuracies are: 0.3070707
# ## Experiment: Severity = 2, corruption = frost, shot_size = 15
# Correct:  275./ 990. (27.78 %)
# One_shot_accuracies are: 0.2777778
# ## Experiment: Severity = 2, corruption = fog, shot_size = 15
# Correct:  375./ 990. (37.88 %)
# One_shot_accuracies are: 0.37878788
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 15
# Correct:  551./ 990. (55.66 %)
# One_shot_accuracies are: 0.55656564
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 15
# Correct:  425./ 990. (42.93 %)
# One_shot_accuracies are: 0.42929292
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 15
# Correct:  329./ 990. (33.23 %)
# One_shot_accuracies are: 0.33232322
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 15
# Correct:  525./ 990. (53.03 %)
# One_shot_accuracies are: 0.530303
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 15
# Correct:  405./ 990. (40.91 %)
# One_shot_accuracies are: 0.4090909
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 15
# Correct:  263./ 990. (26.57 %)
# One_shot_accuracies are: 0.26565656
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 20
# Correct:  310./1000. (31.00 %)
# One_shot_accuracies are: 0.31
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 20
# Correct:  404./1000. (40.40 %)
# One_shot_accuracies are: 0.404
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 20
# Correct:  480./1000. (48.00 %)
# One_shot_accuracies are: 0.48
# ## Experiment: Severity = 2, corruption = snow, shot_size = 20
# Correct:  248./1000. (24.80 %)
# One_shot_accuracies are: 0.248
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 20
# Correct:  312./1000. (31.20 %)
# One_shot_accuracies are: 0.312
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 20
# Correct:  361./1000. (36.10 %)
# One_shot_accuracies are: 0.361
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 20
# Correct:  499./1000. (49.90 %)
# One_shot_accuracies are: 0.499
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 20
# Correct:  334./1000. (33.40 %)
# One_shot_accuracies are: 0.334
# ## Experiment: Severity = 2, corruption = frost, shot_size = 20
# Correct:  323./1000. (32.30 %)
# One_shot_accuracies are: 0.323
# ## Experiment: Severity = 2, corruption = fog, shot_size = 20
# Correct:  448./1000. (44.80 %)
# One_shot_accuracies are: 0.448
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 20
# Correct:  554./1000. (55.40 %)
# One_shot_accuracies are: 0.554
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 20
# Correct:  451./1000. (45.10 %)
# One_shot_accuracies are: 0.451
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 20
# Correct:  352./1000. (35.20 %)
# One_shot_accuracies are: 0.352
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 20
# Correct:  514./1000. (51.40 %)
# One_shot_accuracies are: 0.514
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 20
# Correct:  425./1000. (42.50 %)
# One_shot_accuracies are: 0.425
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 20
# Correct:  303./1000. (30.30 %)
# One_shot_accuracies are: 0.303
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 25
# Correct:  332./1000. (33.20 %)
# One_shot_accuracies are: 0.332
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 25
# Correct:  413./1000. (41.30 %)
# One_shot_accuracies are: 0.413
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 25
# Correct:  491./1000. (49.10 %)
# One_shot_accuracies are: 0.491
# ## Experiment: Severity = 2, corruption = snow, shot_size = 25
# Correct:  291./1000. (29.10 %)
# One_shot_accuracies are: 0.291
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 25
# Correct:  320./1000. (32.00 %)
# One_shot_accuracies are: 0.32
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 25
# Correct:  381./1000. (38.10 %)
# One_shot_accuracies are: 0.381
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 25
# Correct:  533./1000. (53.30 %)
# One_shot_accuracies are: 0.533
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 25
# Correct:  348./1000. (34.80 %)
# One_shot_accuracies are: 0.348
# ## Experiment: Severity = 2, corruption = frost, shot_size = 25
# Correct:  299./1000. (29.90 %)
# One_shot_accuracies are: 0.299
# ## Experiment: Severity = 2, corruption = fog, shot_size = 25
# Correct:  432./1000. (43.20 %)
# One_shot_accuracies are: 0.432
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 25
# Correct:  588./1000. (58.80 %)
# One_shot_accuracies are: 0.588
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 25
# Correct:  485./1000. (48.50 %)
# One_shot_accuracies are: 0.485
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 25
# Correct:  327./1000. (32.70 %)
# One_shot_accuracies are: 0.327
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 25
# Correct:  541./1000. (54.10 %)
# One_shot_accuracies are: 0.541
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 25
# Correct:  412./1000. (41.20 %)
# One_shot_accuracies are: 0.412
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 25
# Correct:  309./1000. (30.90 %)
# One_shot_accuracies are: 0.309
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 30
# Correct:  334./ 990. (33.74 %)
# One_shot_accuracies are: 0.33737373
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 30
# Correct:  437./ 990. (44.14 %)
# One_shot_accuracies are: 0.44141415
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 30
# Correct:  484./ 990. (48.89 %)
# One_shot_accuracies are: 0.4888889
# ## Experiment: Severity = 2, corruption = snow, shot_size = 30
# Correct:  264./ 990. (26.67 %)
# One_shot_accuracies are: 0.26666668
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 30
# Correct:  305./ 990. (30.81 %)
# One_shot_accuracies are: 0.30808082
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 30
# Correct:  356./ 990. (35.96 %)
# One_shot_accuracies are: 0.35959595
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 30
# Correct:  514./ 990. (51.92 %)
# One_shot_accuracies are: 0.5191919
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 30
# Correct:  320./ 990. (32.32 %)
# One_shot_accuracies are: 0.32323232
# ## Experiment: Severity = 2, corruption = frost, shot_size = 30
# Correct:  319./ 990. (32.22 %)
# One_shot_accuracies are: 0.32222223
# ## Experiment: Severity = 2, corruption = fog, shot_size = 30
# Correct:  444./ 990. (44.85 %)
# One_shot_accuracies are: 0.44848484
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 30
# Correct:  592./ 990. (59.80 %)
# One_shot_accuracies are: 0.5979798
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 30
# Correct:  481./ 990. (48.59 %)
# One_shot_accuracies are: 0.4858586
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 30
# Correct:  366./ 990. (36.97 %)
# One_shot_accuracies are: 0.36969697
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 30
# Correct:  538./ 990. (54.34 %)
# One_shot_accuracies are: 0.5434343
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 30
# Correct:  433./ 990. (43.74 %)
# One_shot_accuracies are: 0.43737373
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 30
# Correct:  277./ 990. (27.98 %)
# One_shot_accuracies are: 0.27979797
# ## Experiment: Severity = 2, corruption = zoom_blur, shot_size = 32
# Correct:  329./ 992. (33.17 %)
# One_shot_accuracies are: 0.33165324
# ## Experiment: Severity = 2, corruption = speckle_noise, shot_size = 32
# Correct:  418./ 992. (42.14 %)
# One_shot_accuracies are: 0.42137095
# ## Experiment: Severity = 2, corruption = spatter, shot_size = 32
# Correct:  477./ 992. (48.08 %)
# One_shot_accuracies are: 0.48084676
# ## Experiment: Severity = 2, corruption = snow, shot_size = 32
# Correct:  276./ 992. (27.82 %)
# One_shot_accuracies are: 0.2782258
# ## Experiment: Severity = 2, corruption = glass_blur, shot_size = 32
# Correct:  325./ 992. (32.76 %)
# One_shot_accuracies are: 0.32762095
# ## Experiment: Severity = 2, corruption = motion_blur, shot_size = 32
# Correct:  345./ 992. (34.78 %)
# One_shot_accuracies are: 0.34778225
# ## Experiment: Severity = 2, corruption = saturate, shot_size = 32
# Correct:  545./ 992. (54.94 %)
# One_shot_accuracies are: 0.54939514
# ## Experiment: Severity = 2, corruption = gaussian_blur, shot_size = 32
# Correct:  295./ 992. (29.74 %)
# One_shot_accuracies are: 0.29737905
# ## Experiment: Severity = 2, corruption = frost, shot_size = 32
# Correct:  302./ 992. (30.44 %)
# One_shot_accuracies are: 0.3044355
# ## Experiment: Severity = 2, corruption = fog, shot_size = 32
# Correct:  408./ 992. (41.13 %)
# One_shot_accuracies are: 0.41129032
# ## Experiment: Severity = 2, corruption = brightness, shot_size = 32
# Correct:  595./ 992. (59.98 %)
# One_shot_accuracies are: 0.5997984
# ## Experiment: Severity = 2, corruption = contrast, shot_size = 32
# Correct:  464./ 992. (46.77 %)
# One_shot_accuracies are: 0.46774194
# ## Experiment: Severity = 2, corruption = elastic_transform, shot_size = 32
# Correct:  375./ 992. (37.80 %)
# One_shot_accuracies are: 0.3780242
# ## Experiment: Severity = 2, corruption = pixelate, shot_size = 32
# Correct:  528./ 992. (53.23 %)
# One_shot_accuracies are: 0.5322581
# ## Experiment: Severity = 2, corruption = jpeg_compression, shot_size = 32
# Correct:  450./ 992. (45.36 %)
# One_shot_accuracies are: 0.45362905
# ## Experiment: Severity = 2, corruption = defocus_blur, shot_size = 32
# Correct:  309./ 992. (31.15 %)
# One_shot_accuracies are: 0.31149194
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = snow, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 1
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: 0.003
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 3, corruption = frost, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = fog, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 1
# Correct:    2./1000. (0.20 %)
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 1
# Correct:    3./1000. (0.30 %)
# One_shot_accuracies are: 0.003
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 5
# Correct:  176./1000. (17.60 %)
# One_shot_accuracies are: 0.176
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 5
# Correct:  212./1000. (21.20 %)
# One_shot_accuracies are: 0.212
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 5
# Correct:  289./1000. (28.90 %)
# One_shot_accuracies are: 0.289
# ## Experiment: Severity = 3, corruption = snow, shot_size = 5
# Correct:  189./1000. (18.90 %)
# One_shot_accuracies are: 0.189
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 5
# Correct:   95./1000. (9.50 %)
# One_shot_accuracies are: 0.095
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 5
# Correct:  191./1000. (19.10 %)
# One_shot_accuracies are: 0.191
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 5
# Correct:  456./1000. (45.60 %)
# One_shot_accuracies are: 0.456
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 5
# Correct:  122./1000. (12.20 %)
# One_shot_accuracies are: 0.122
# ## Experiment: Severity = 3, corruption = frost, shot_size = 5
# Correct:  166./1000. (16.60 %)
# One_shot_accuracies are: 0.166
# ## Experiment: Severity = 3, corruption = fog, shot_size = 5
# Correct:  253./1000. (25.30 %)
# One_shot_accuracies are: 0.253
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 5
# Correct:  461./1000. (46.10 %)
# One_shot_accuracies are: 0.461
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 5
# Correct:  242./1000. (24.20 %)
# One_shot_accuracies are: 0.242
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 5
# Correct:  397./1000. (39.70 %)
# One_shot_accuracies are: 0.397
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 5
# Correct:  319./1000. (31.90 %)
# One_shot_accuracies are: 0.319
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 5
# Correct:  282./1000. (28.20 %)
# One_shot_accuracies are: 0.282
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 5
# Correct:  116./1000. (11.60 %)
# One_shot_accuracies are: 0.116
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 10
# Correct:  230./1000. (23.00 %)
# One_shot_accuracies are: 0.23
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 10
# Correct:  250./1000. (25.00 %)
# One_shot_accuracies are: 0.25
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 10
# Correct:  371./1000. (37.10 %)
# One_shot_accuracies are: 0.371
# ## Experiment: Severity = 3, corruption = snow, shot_size = 10
# Correct:  250./1000. (25.00 %)
# One_shot_accuracies are: 0.25
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 10
# Correct:  138./1000. (13.80 %)
# One_shot_accuracies are: 0.138
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 10
# Correct:  229./1000. (22.90 %)
# One_shot_accuracies are: 0.229
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 10
# Correct:  570./1000. (57.00 %)
# One_shot_accuracies are: 0.57
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 10
# Correct:  179./1000. (17.90 %)
# One_shot_accuracies are: 0.179
# ## Experiment: Severity = 3, corruption = frost, shot_size = 10
# Correct:  215./1000. (21.50 %)
# One_shot_accuracies are: 0.215
# ## Experiment: Severity = 3, corruption = fog, shot_size = 10
# Correct:  341./1000. (34.10 %)
# One_shot_accuracies are: 0.341
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 10
# Correct:  483./1000. (48.30 %)
# One_shot_accuracies are: 0.483
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 10
# Correct:  297./1000. (29.70 %)
# One_shot_accuracies are: 0.297
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 10
# Correct:  414./1000. (41.40 %)
# One_shot_accuracies are: 0.414
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 10
# Correct:  398./1000. (39.80 %)
# One_shot_accuracies are: 0.398
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 10
# Correct:  361./1000. (36.10 %)
# One_shot_accuracies are: 0.361
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 10
# Correct:  147./1000. (14.70 %)
# One_shot_accuracies are: 0.147
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 15
# Correct:  276./ 990. (27.88 %)
# One_shot_accuracies are: 0.27878788
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 15
# Correct:  264./ 990. (26.67 %)
# One_shot_accuracies are: 0.26666668
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 15
# Correct:  367./ 990. (37.07 %)
# One_shot_accuracies are: 0.37070706
# ## Experiment: Severity = 3, corruption = snow, shot_size = 15
# Correct:  226./ 990. (22.83 %)
# One_shot_accuracies are: 0.22828282
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 15
# Correct:  150./ 990. (15.15 %)
# One_shot_accuracies are: 0.15151516
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 15
# Correct:  229./ 990. (23.13 %)
# One_shot_accuracies are: 0.23131312
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 15
# Correct:  573./ 990. (57.88 %)
# One_shot_accuracies are: 0.57878786
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 15
# Correct:  194./ 990. (19.60 %)
# One_shot_accuracies are: 0.1959596
# ## Experiment: Severity = 3, corruption = frost, shot_size = 15
# Correct:  198./ 990. (20.00 %)
# One_shot_accuracies are: 0.2
# ## Experiment: Severity = 3, corruption = fog, shot_size = 15
# Correct:  366./ 990. (36.97 %)
# One_shot_accuracies are: 0.36969697
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 15
# Correct:  532./ 990. (53.74 %)
# One_shot_accuracies are: 0.5373737
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 15
# Correct:  313./ 990. (31.62 %)
# One_shot_accuracies are: 0.3161616
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 15
# Correct:  421./ 990. (42.53 %)
# One_shot_accuracies are: 0.42525253
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 15
# Correct:  431./ 990. (43.54 %)
# One_shot_accuracies are: 0.43535355
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 15
# Correct:  390./ 990. (39.39 %)
# One_shot_accuracies are: 0.3939394
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 15
# Correct:  163./ 990. (16.46 %)
# One_shot_accuracies are: 0.16464646
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 20
# Correct:  283./1000. (28.30 %)
# One_shot_accuracies are: 0.283
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 20
# Correct:  290./1000. (29.00 %)
# One_shot_accuracies are: 0.29
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 20
# Correct:  414./1000. (41.40 %)
# One_shot_accuracies are: 0.414
# ## Experiment: Severity = 3, corruption = snow, shot_size = 20
# Correct:  266./1000. (26.60 %)
# One_shot_accuracies are: 0.266
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 20
# Correct:  158./1000. (15.80 %)
# One_shot_accuracies are: 0.158
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 20
# Correct:  254./1000. (25.40 %)
# One_shot_accuracies are: 0.254
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 20
# Correct:  570./1000. (57.00 %)
# One_shot_accuracies are: 0.57
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 20
# Correct:  212./1000. (21.20 %)
# One_shot_accuracies are: 0.212
# ## Experiment: Severity = 3, corruption = frost, shot_size = 20
# Correct:  224./1000. (22.40 %)
# One_shot_accuracies are: 0.224
# ## Experiment: Severity = 3, corruption = fog, shot_size = 20
# Correct:  376./1000. (37.60 %)
# One_shot_accuracies are: 0.376
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 20
# Correct:  529./1000. (52.90 %)
# One_shot_accuracies are: 0.529
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 20
# Correct:  352./1000. (35.20 %)
# One_shot_accuracies are: 0.352
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 20
# Correct:  464./1000. (46.40 %)
# One_shot_accuracies are: 0.464
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 20
# Correct:  479./1000. (47.90 %)
# One_shot_accuracies are: 0.479
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 20
# Correct:  375./1000. (37.50 %)
# One_shot_accuracies are: 0.375
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 20
# Correct:  167./1000. (16.70 %)
# One_shot_accuracies are: 0.167
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 25
# Correct:  279./1000. (27.90 %)
# One_shot_accuracies are: 0.279
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 25
# Correct:  292./1000. (29.20 %)
# One_shot_accuracies are: 0.292
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 25
# Correct:  415./1000. (41.50 %)
# One_shot_accuracies are: 0.415
# ## Experiment: Severity = 3, corruption = snow, shot_size = 25
# Correct:  236./1000. (23.60 %)
# One_shot_accuracies are: 0.236
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 25
# Correct:  149./1000. (14.90 %)
# One_shot_accuracies are: 0.149
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 25
# Correct:  257./1000. (25.70 %)
# One_shot_accuracies are: 0.257
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 25
# Correct:  589./1000. (58.90 %)
# One_shot_accuracies are: 0.589
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 25
# Correct:  185./1000. (18.50 %)
# One_shot_accuracies are: 0.185
# ## Experiment: Severity = 3, corruption = frost, shot_size = 25
# Correct:  217./1000. (21.70 %)
# One_shot_accuracies are: 0.217
# ## Experiment: Severity = 3, corruption = fog, shot_size = 25
# Correct:  383./1000. (38.30 %)
# One_shot_accuracies are: 0.383
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 25
# Correct:  538./1000. (53.80 %)
# One_shot_accuracies are: 0.538
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 25
# Correct:  331./1000. (33.10 %)
# One_shot_accuracies are: 0.331
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 25
# Correct:  470./1000. (47.00 %)
# One_shot_accuracies are: 0.47
# ## Experiment: Severity = 3, corruption = pixelate, shot_size = 25
# Correct:  427./1000. (42.70 %)
# One_shot_accuracies are: 0.427
# ## Experiment: Severity = 3, corruption = jpeg_compression, shot_size = 25
# Correct:  420./1000. (42.00 %)
# One_shot_accuracies are: 0.42
# ## Experiment: Severity = 3, corruption = defocus_blur, shot_size = 25
# Correct:  162./1000. (16.20 %)
# One_shot_accuracies are: 0.162
# ## Experiment: Severity = 3, corruption = zoom_blur, shot_size = 30
# Correct:  302./ 990. (30.51 %)
# One_shot_accuracies are: 0.3050505
# ## Experiment: Severity = 3, corruption = speckle_noise, shot_size = 30
# Correct:  307./ 990. (31.01 %)
# One_shot_accuracies are: 0.310101
# ## Experiment: Severity = 3, corruption = spatter, shot_size = 30
# Correct:  405./ 990. (40.91 %)
# One_shot_accuracies are: 0.4090909
# ## Experiment: Severity = 3, corruption = snow, shot_size = 30
# Correct:  263./ 990. (26.57 %)
# One_shot_accuracies are: 0.26565656
# ## Experiment: Severity = 3, corruption = glass_blur, shot_size = 30
# Correct:  166./ 990. (16.77 %)
# One_shot_accuracies are: 0.16767676
# ## Experiment: Severity = 3, corruption = motion_blur, shot_size = 30
# Correct:  245./ 990. (24.75 %)
# One_shot_accuracies are: 0.24747474
# ## Experiment: Severity = 3, corruption = saturate, shot_size = 30
# Correct:  567./ 990. (57.27 %)
# One_shot_accuracies are: 0.57272726
# ## Experiment: Severity = 3, corruption = gaussian_blur, shot_size = 30
# Correct:  220./ 990. (22.22 %)
# One_shot_accuracies are: 0.22222222
# ## Experiment: Severity = 3, corruption = frost, shot_size = 30
# Correct:  234./ 990. (23.64 %)
# One_shot_accuracies are: 0.23636363
# ## Experiment: Severity = 3, corruption = fog, shot_size = 30
# Correct:  353./ 990. (35.66 %)
# One_shot_accuracies are: 0.35656565
# ## Experiment: Severity = 3, corruption = brightness, shot_size = 30
# Correct:  553./ 990. (55.86 %)
# One_shot_accuracies are: 0.5585859
# ## Experiment: Severity = 3, corruption = contrast, shot_size = 30
# Correct:  342./ 990. (34.55 %)
# One_shot_accuracies are: 0.34545454
# ## Experiment: Severity = 3, corruption = elastic_transform, shot_size = 30
# Correct:  461./ 990. (46.57 %)
# ...
# One_shot_accuracies are: 0.002
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 5, corruption = frost, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 5, corruption = fog, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 1
# Correct:    1./1000. (0.10 %)
# One_shot_accuracies are: 0.001
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 1
# Correct:    0./1000. (0.00 %)
# One_shot_accuracies are: 0.0
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 5
# Correct:  132./1000. (13.20 %)
# One_shot_accuracies are: 0.132
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 5
# Correct:   97./1000. (9.70 %)
# One_shot_accuracies are: 0.097
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 5
# Correct:  190./1000. (19.00 %)
# One_shot_accuracies are: 0.19
# ## Experiment: Severity = 5, corruption = snow, shot_size = 5
# Correct:  109./1000. (10.90 %)
# One_shot_accuracies are: 0.109
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 5
# Correct:   42./1000. (4.20 %)
# One_shot_accuracies are: 0.042
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 5
# Correct:   49./1000. (4.90 %)
# One_shot_accuracies are: 0.049
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 5
# Correct:  285./1000. (28.50 %)
# One_shot_accuracies are: 0.285
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 5
# Correct:   35./1000. (3.50 %)
# One_shot_accuracies are: 0.035
# ## Experiment: Severity = 5, corruption = frost, shot_size = 5
# Correct:  130./1000. (13.00 %)
# One_shot_accuracies are: 0.13
# ## Experiment: Severity = 5, corruption = fog, shot_size = 5
# Correct:  158./1000. (15.80 %)
# One_shot_accuracies are: 0.158
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 5
# Correct:  340./1000. (34.00 %)
# One_shot_accuracies are: 0.34
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 5
# Correct:   10./1000. (1.00 %)
# One_shot_accuracies are: 0.01
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 5
# Correct:  184./1000. (18.40 %)
# One_shot_accuracies are: 0.184
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 5
# Correct:  180./1000. (18.00 %)
# One_shot_accuracies are: 0.18
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 5
# Correct:  125./1000. (12.50 %)
# One_shot_accuracies are: 0.125
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 5
# Correct:   39./1000. (3.90 %)
# One_shot_accuracies are: 0.039
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 10
# Correct:  198./1000. (19.80 %)
# One_shot_accuracies are: 0.198
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 10
# Correct:  137./1000. (13.70 %)
# One_shot_accuracies are: 0.137
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 10
# Correct:  227./1000. (22.70 %)
# One_shot_accuracies are: 0.227
# ## Experiment: Severity = 5, corruption = snow, shot_size = 10
# Correct:  127./1000. (12.70 %)
# One_shot_accuracies are: 0.127
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 10
# Correct:   48./1000. (4.80 %)
# One_shot_accuracies are: 0.048
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 10
# Correct:  100./1000. (10.00 %)
# One_shot_accuracies are: 0.1
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 10
# Correct:  343./1000. (34.30 %)
# One_shot_accuracies are: 0.343
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 10
# Correct:   50./1000. (5.00 %)
# One_shot_accuracies are: 0.05
# ## Experiment: Severity = 5, corruption = frost, shot_size = 10
# Correct:  136./1000. (13.60 %)
# One_shot_accuracies are: 0.136
# ## Experiment: Severity = 5, corruption = fog, shot_size = 10
# Correct:  206./1000. (20.60 %)
# One_shot_accuracies are: 0.206
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 10
# Correct:  414./1000. (41.40 %)
# One_shot_accuracies are: 0.414
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 10
# Correct:   17./1000. (1.70 %)
# One_shot_accuracies are: 0.017
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 10
# Correct:  201./1000. (20.10 %)
# One_shot_accuracies are: 0.201
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 10
# Correct:  261./1000. (26.10 %)
# One_shot_accuracies are: 0.261
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 10
# Correct:  176./1000. (17.60 %)
# One_shot_accuracies are: 0.176
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 10
# Correct:   49./1000. (4.90 %)
# One_shot_accuracies are: 0.049
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 15
# Correct:  176./ 990. (17.78 %)
# One_shot_accuracies are: 0.17777778
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 15
# Correct:  135./ 990. (13.64 %)
# One_shot_accuracies are: 0.13636364
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 15
# Correct:  226./ 990. (22.83 %)
# One_shot_accuracies are: 0.22828282
# ## Experiment: Severity = 5, corruption = snow, shot_size = 15
# Correct:  172./ 990. (17.37 %)
# One_shot_accuracies are: 0.17373738
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 15
# Correct:   64./ 990. (6.46 %)
# One_shot_accuracies are: 0.06464647
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 15
# Correct:  100./ 990. (10.10 %)
# One_shot_accuracies are: 0.1010101
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 15
# Correct:  343./ 990. (34.65 %)
# One_shot_accuracies are: 0.34646463
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 15
# Correct:   52./ 990. (5.25 %)
# One_shot_accuracies are: 0.052525252
# ## Experiment: Severity = 5, corruption = frost, shot_size = 15
# Correct:  149./ 990. (15.05 %)
# One_shot_accuracies are: 0.15050505
# ## Experiment: Severity = 5, corruption = fog, shot_size = 15
# Correct:  209./ 990. (21.11 %)
# One_shot_accuracies are: 0.21111111
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 15
# Correct:  429./ 990. (43.33 %)
# One_shot_accuracies are: 0.43333334
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 15
# Correct:    8./ 990. (0.81 %)
# One_shot_accuracies are: 0.008080808
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 15
# Correct:  253./ 990. (25.56 %)
# One_shot_accuracies are: 0.25555557
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 15
# Correct:  266./ 990. (26.87 %)
# One_shot_accuracies are: 0.26868686
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 15
# Correct:  160./ 990. (16.16 %)
# One_shot_accuracies are: 0.16161616
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 15
# Correct:   68./ 990. (6.87 %)
# One_shot_accuracies are: 0.068686865
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 20
# Correct:  204./1000. (20.40 %)
# One_shot_accuracies are: 0.204
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 20
# Correct:  144./1000. (14.40 %)
# One_shot_accuracies are: 0.144
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 20
# Correct:  245./1000. (24.50 %)
# One_shot_accuracies are: 0.245
# ## Experiment: Severity = 5, corruption = snow, shot_size = 20
# Correct:  154./1000. (15.40 %)
# One_shot_accuracies are: 0.154
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 20
# Correct:   89./1000. (8.90 %)
# One_shot_accuracies are: 0.089
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 20
# Correct:   87./1000. (8.70 %)
# One_shot_accuracies are: 0.087
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 20
# Correct:  382./1000. (38.20 %)
# One_shot_accuracies are: 0.382
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 20
# Correct:   31./1000. (3.10 %)
# One_shot_accuracies are: 0.031
# ## Experiment: Severity = 5, corruption = frost, shot_size = 20
# Correct:  156./1000. (15.60 %)
# One_shot_accuracies are: 0.156
# ## Experiment: Severity = 5, corruption = fog, shot_size = 20
# Correct:  201./1000. (20.10 %)
# One_shot_accuracies are: 0.201
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 20
# Correct:  459./1000. (45.90 %)
# One_shot_accuracies are: 0.459
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 20
# Correct:   10./1000. (1.00 %)
# One_shot_accuracies are: 0.01
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 20
# Correct:  264./1000. (26.40 %)
# One_shot_accuracies are: 0.264
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 20
# Correct:  236./1000. (23.60 %)
# One_shot_accuracies are: 0.236
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 20
# Correct:  168./1000. (16.80 %)
# One_shot_accuracies are: 0.168
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 20
# Correct:   64./1000. (6.40 %)
# One_shot_accuracies are: 0.064
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 25
# Correct:  206./1000. (20.60 %)
# One_shot_accuracies are: 0.206
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 25
# Correct:  141./1000. (14.10 %)
# One_shot_accuracies are: 0.141
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 25
# Correct:  224./1000. (22.40 %)
# One_shot_accuracies are: 0.224
# ## Experiment: Severity = 5, corruption = snow, shot_size = 25
# Correct:  164./1000. (16.40 %)
# One_shot_accuracies are: 0.164
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 25
# Correct:   77./1000. (7.70 %)
# One_shot_accuracies are: 0.077
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 25
# Correct:   90./1000. (9.00 %)
# One_shot_accuracies are: 0.09
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 25
# Correct:  443./1000. (44.30 %)
# One_shot_accuracies are: 0.443
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 25
# Correct:   51./1000. (5.10 %)
# One_shot_accuracies are: 0.051
# ## Experiment: Severity = 5, corruption = frost, shot_size = 25
# Correct:  167./1000. (16.70 %)
# One_shot_accuracies are: 0.167
# ## Experiment: Severity = 5, corruption = fog, shot_size = 25
# Correct:  273./1000. (27.30 %)
# One_shot_accuracies are: 0.273
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 25
# Correct:  442./1000. (44.20 %)
# One_shot_accuracies are: 0.442
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 25
# Correct:   21./1000. (2.10 %)
# One_shot_accuracies are: 0.021
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 25
# Correct:  245./1000. (24.50 %)
# One_shot_accuracies are: 0.245
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 25
# Correct:  265./1000. (26.50 %)
# One_shot_accuracies are: 0.265
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 25
# Correct:  163./1000. (16.30 %)
# One_shot_accuracies are: 0.163
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 25
# Correct:   62./1000. (6.20 %)
# One_shot_accuracies are: 0.062
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 30
# Correct:  222./ 990. (22.42 %)
# One_shot_accuracies are: 0.22424242
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 30
# Correct:  155./ 990. (15.66 %)
# One_shot_accuracies are: 0.15656565
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 30
# Correct:  237./ 990. (23.94 %)
# One_shot_accuracies are: 0.23939393
# ## Experiment: Severity = 5, corruption = snow, shot_size = 30
# Correct:  169./ 990. (17.07 %)
# One_shot_accuracies are: 0.17070708
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 30
# Correct:   83./ 990. (8.38 %)
# One_shot_accuracies are: 0.08383838
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 30
# Correct:  111./ 990. (11.21 %)
# One_shot_accuracies are: 0.11212121
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 30
# Correct:  419./ 990. (42.32 %)
# One_shot_accuracies are: 0.42323232
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 30
# Correct:   43./ 990. (4.34 %)
# One_shot_accuracies are: 0.043434344
# ## Experiment: Severity = 5, corruption = frost, shot_size = 30
# Correct:  169./ 990. (17.07 %)
# One_shot_accuracies are: 0.17070708
# ## Experiment: Severity = 5, corruption = fog, shot_size = 30
# Correct:  235./ 990. (23.74 %)
# One_shot_accuracies are: 0.23737374
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 30
# Correct:  454./ 990. (45.86 %)
# One_shot_accuracies are: 0.45858586
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 30
# Correct:   19./ 990. (1.92 %)
# One_shot_accuracies are: 0.019191919
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 30
# Correct:  295./ 990. (29.80 %)
# One_shot_accuracies are: 0.2979798
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 30
# Correct:  255./ 990. (25.76 %)
# One_shot_accuracies are: 0.25757575
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 30
# Correct:  174./ 990. (17.58 %)
# One_shot_accuracies are: 0.17575757
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 30
# Correct:   53./ 990. (5.35 %)
# One_shot_accuracies are: 0.053535353
# ## Experiment: Severity = 5, corruption = zoom_blur, shot_size = 32
# Correct:  189./ 992. (19.05 %)
# One_shot_accuracies are: 0.19052419
# ## Experiment: Severity = 5, corruption = speckle_noise, shot_size = 32
# Correct:  150./ 992. (15.12 %)
# One_shot_accuracies are: 0.15120968
# ## Experiment: Severity = 5, corruption = spatter, shot_size = 32
# Correct:  241./ 992. (24.29 %)
# One_shot_accuracies are: 0.24294356
# ## Experiment: Severity = 5, corruption = snow, shot_size = 32
# Correct:  154./ 992. (15.52 %)
# One_shot_accuracies are: 0.15524194
# ## Experiment: Severity = 5, corruption = glass_blur, shot_size = 32
# Correct:   65./ 992. (6.55 %)
# One_shot_accuracies are: 0.06552419
# ## Experiment: Severity = 5, corruption = motion_blur, shot_size = 32
# Correct:  121./ 992. (12.20 %)
# One_shot_accuracies are: 0.12197581
# ## Experiment: Severity = 5, corruption = saturate, shot_size = 32
# Correct:  384./ 992. (38.71 %)
# One_shot_accuracies are: 0.38709676
# ## Experiment: Severity = 5, corruption = gaussian_blur, shot_size = 32
# Correct:   50./ 992. (5.04 %)
# One_shot_accuracies are: 0.050403226
# ## Experiment: Severity = 5, corruption = frost, shot_size = 32
# Correct:  168./ 992. (16.94 %)
# One_shot_accuracies are: 0.16935484
# ## Experiment: Severity = 5, corruption = fog, shot_size = 32
# Correct:  248./ 992. (25.00 %)
# One_shot_accuracies are: 0.25
# ## Experiment: Severity = 5, corruption = brightness, shot_size = 32
# Correct:  446./ 992. (44.96 %)
# One_shot_accuracies are: 0.44959676
# ## Experiment: Severity = 5, corruption = contrast, shot_size = 32
# Correct:   22./ 992. (2.22 %)
# One_shot_accuracies are: 0.022177419
# ## Experiment: Severity = 5, corruption = elastic_transform, shot_size = 32
# Correct:  264./ 992. (26.61 %)
# One_shot_accuracies are: 0.26612905
# ## Experiment: Severity = 5, corruption = pixelate, shot_size = 32
# Correct:  267./ 992. (26.92 %)
# One_shot_accuracies are: 0.26915324
# ## Experiment: Severity = 5, corruption = jpeg_compression, shot_size = 32
# Correct:  178./ 992. (17.94 %)
# One_shot_accuracies are: 0.17943548
# ## Experiment: Severity = 5, corruption = defocus_blur, shot_size = 32
# Correct:   53./ 992. (5.34 %)
# One_shot_accuracies are: 0.05342742

# %%
with open('rpl_few_shot_acc.npy', 'rb') as f:
    rpl_few_shot_acc = np.load(f)

# %%
rpl_few_shot_acc
# Out:
# array([[[0.001     , 0.315     , 0.389     , 0.39292929, 0.38999999,
#          0.36500001, 0.38989899, 0.37903225],
#         [0.002     , 0.241     , 0.308     , 0.31212121, 0.31      ,
#          0.33199999, 0.33737373, 0.33165324],
#         [0.001     , 0.176     , 0.23      , 0.27878788, 0.28299999,
#          0.27900001, 0.30505049, 0.28830644],
#         [0.002     , 0.162     , 0.2       , 0.19797979, 0.233     ,
#          0.23899999, 0.24040404, 0.21774194],
#         [0.        , 0.132     , 0.198     , 0.17777778, 0.204     ,
#          0.206     , 0.22424242, 0.19052419]],
#
#        [[0.001     , 0.38800001, 0.44      , 0.47272727, 0.486     ,
#          0.331     , 0.34545454, 0.3639113 ],
#         [0.002     , 0.099     , 0.114     , 0.11818182, 0.133     ,
#          0.116     , 0.15252525, 0.14415322],
#         [0.001     , 0.01      , 0.017     , 0.00808081, 0.01      ,
#          0.021     , 0.01919192, 0.02217742]],
#
#        [[0.003     , 0.421     , 0.48899999, 0.49494949, 0.52200001,
#          0.55000001, 0.53434342, 0.53125   ],
#         [0.        , 0.266     , 0.31999999, 0.33232322, 0.352     ,
#          0.32699999, 0.36969697, 0.37802419],
#         [0.001     , 0.39700001, 0.414     , 0.42525253, 0.46399999,
#          0.47      , 0.46565658, 0.47479838],
#         [0.        , 0.30500001, 0.34599999, 0.42525253, 0.384     ,
#          0.38      , 0.39393941, 0.39616936],
#         [0.        , 0.184     , 0.20100001, 0.25555557, 0.264     ,
#          0.245     , 0.2979798 , 0.26612905]],
#
#        [[0.        , 0.43900001, 0.50800002, 0.54040402, 0.528     ,
#          0.551     , 0.55050504, 0.55443549],
#         [0.        , 0.43799999, 0.50400001, 0.530303  , 0.514     ,
#          0.54100001, 0.54343432, 0.53225809],
#         [0.003     , 0.31900001, 0.398     , 0.43535355, 0.479     ,
#          0.42699999, 0.44444445, 0.45161289],
#         [0.001     , 0.23199999, 0.31299999, 0.33434343, 0.322     ,
#          0.33199999, 0.31515151, 0.34576613],
#         [0.001     , 0.18000001, 0.26100001, 0.26868686, 0.236     ,
#          0.26499999, 0.25757575, 0.26915324]],
#
#        [[0.001     , 0.36500001, 0.45699999, 0.4848485 , 0.52700001,
#          0.52499998, 0.4878788 , 0.49193549],
#         [0.        , 0.32499999, 0.414     , 0.40909091, 0.42500001,
#          0.412     , 0.43737373, 0.45362905],
#         [0.001     , 0.28200001, 0.361     , 0.39393941, 0.375     ,
#          0.41999999, 0.37979797, 0.39112905],
#         [0.        , 0.18799999, 0.273     , 0.2888889 , 0.289     ,
#          0.241     , 0.27777779, 0.28629032],
#         [0.001     , 0.125     , 0.176     , 0.16161616, 0.168     ,
#          0.163     , 0.17575757, 0.17943548]],
#
#        [[0.002     , 0.28999999, 0.359     , 0.39898989, 0.36000001,
#          0.352     , 0.35656565, 0.375     ],
#         [0.        , 0.205     , 0.259     , 0.26565656, 0.303     ,
#          0.30899999, 0.27979797, 0.31149194],
#         [0.        , 0.116     , 0.147     , 0.16464646, 0.167     ,
#          0.162     , 0.18282828, 0.15524194],
#         [0.        , 0.062     , 0.092     , 0.1       , 0.09      ,
#          0.111     , 0.11212121, 0.12802419],
#         [0.        , 0.039     , 0.049     , 0.06868687, 0.064     ,
#          0.062     , 0.05353535, 0.05342742]]])

# %% [markdown]
# # Graphs

# %%
import matplotlib.pyplot as plt

# %%
# severity 5, 16 graphs for 16 corruptions, 
# 6 lines for 6 batch sizes, an extra line for baseline corruption, an extra line for ref

# %%
with open('ResNet50_performances.npy', 'rb') as f:
    baseline_performances = np.load(f)
with open('ResNet50_times.npy', 'rb') as f:
    baseline_inf_times = np.load(f)
with open('RPL_corrupt_train_acc.npy', 'rb') as f:
    rpl_corrupt_train_acc = np.load(f)
with open('RPL_corrupt_validation_acc.npy', 'rb') as f:
    rpl_corrupt_val_acc = np.load(f)
with open('RPL_target_acc.npy', 'rb') as f:
    rpl_ref_acc = np.load(f)
with open('RPL_adapt_time.npy', 'rb') as f:
    rpl_adpt_times = np.load(f)

# %%
target_sizes = [32, 64, 128, 256, 512, 1000]
severity = [1,2,3,4,5]
shot_sizes = [1, 5, 10, 15, 20, 25, 30, 32]

# %%
fig, ax = plt.subplots(4,4, figsize=(18, 18))
fig.suptitle('Accuracy on corrupted validation set (size = 1000)')
for cor_ind in range(len(corruption)):
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][0])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][1])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][3])
    ax[cor_ind//4][cor_ind%4].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][4], label='Adapted')
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_train_acc[cor_ind][4], label='corrupted training(adapting) accuracy')
#     ax[cor_ind].plot(target_sizes, rpl_ref_acc[cor_ind][4])
    ax[cor_ind//4][cor_ind%4].plot(target_sizes, baseline_performances[cor_ind][4], label = 'Vanilla Resnet50')
    ax[cor_ind//4][cor_ind%4].legend()
    ax[cor_ind//4][cor_ind%4].set_title('Corruption: '+corruption[cor_ind])
    ax[cor_ind//4][cor_ind%4].set_xticks(target_sizes)
    ax[cor_ind//4][cor_ind%4].set_ylim([0, 0.7])


    
for a in ax.flat:
    a.set(xlabel='Target adaptation batch size', ylabel='Accuracy')
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for a in ax.flat:
    a.label_outer()

# %%
fig, ax = plt.subplots(4,4, figsize=(18, 18))
fig.suptitle('Accuracy on corrupted (severity = 3) validation set')
for cor_ind in range(len(corruption)):
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][0])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][1])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][3])
    ax[cor_ind//4][cor_ind%4].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2], label='Adapted')
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_train_acc[cor_ind][4], label='corrupted training(adapting) accuracy')
#     ax[cor_ind].plot(target_sizes, rpl_ref_acc[cor_ind][4])
    ax[cor_ind//4][cor_ind%4].plot(target_sizes, baseline_performances[cor_ind][2], label = 'Vanilla Resnet50')
    ax[cor_ind//4][cor_ind%4].legend()
    ax[cor_ind//4][cor_ind%4].set_title('Corruption: '+corruption[cor_ind])
    ax[cor_ind//4][cor_ind%4].set_xticks(target_sizes)
    ax[cor_ind//4][cor_ind%4].set_ylim([0, 0.9])


    
for a in ax.flat:
    a.set(xlabel='Target adaptation batch size', ylabel='Accuracy')
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for a in ax.flat:
    a.label_outer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45595/2138679812.py in <module>
#       6 #     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2])
#       7 #     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][3])
# ----> 8     ax[cor_ind//4][cor_ind%4].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2], label='Adapted')
#       9 #     ax[cor_ind].plot(target_sizes, rpl_corrupt_train_acc[cor_ind][4], label='corrupted training(adapting) accuracy')
#      10 #     ax[cor_ind].plot(target_sizes, rpl_ref_acc[cor_ind][4])
#
# NameError: name 'target_sizes' is not defined

# %%
fig, ax = plt.subplots(4,4, figsize=(18, 18))
fig.suptitle('Accuracy on corrupted (severity = 3) validation set')
for cor_ind in range(len(corruption)):
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][0])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][1])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][2])
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_val_acc[cor_ind][3])
    ax[cor_ind//4][cor_ind%4].plot(shot_sizes, rpl_few_shot_acc[cor_ind][2], label='Few Shot Online Adapted')
#     ax[cor_ind].plot(target_sizes, rpl_corrupt_train_acc[cor_ind][4], label='corrupted training(adapting) accuracy')
#     ax[cor_ind].plot(target_sizes, rpl_ref_acc[cor_ind][4])
    ax[cor_ind//4][cor_ind%4].plot(shot_sizes, baseline_performances[cor_ind][2][0].repeat(8), label = 'Vanilla Resnet50')
    ax[cor_ind//4][cor_ind%4].legend()
    ax[cor_ind//4][cor_ind%4].set_title('Corruption: '+corruption[cor_ind])
    ax[cor_ind//4][cor_ind%4].set_xticks(shot_sizes)
    ax[cor_ind//4][cor_ind%4].set_ylim([0, 0.9])


    
for a in ax.flat:
    a.set(xlabel='Target adaptation batch size', ylabel='Accuracy')
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for a in ax.flat:
    a.label_outer()

# %%
baseline_performances[1][2][0].repeat(8)
# Out:
# array([0.35483871, 0.35483871, 0.35483871, 0.35483871, 0.35483871,
#        0.35483871, 0.35483871, 0.35483871])

# %%
ref_dataset_sizes
# Out:
# {'val': 1000, 'test': 1000}

# %%
len(ref_dataloaders['val'])
# Out:
# 391

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=True)
model.eval()
# Out:
# Using cache found in /home/zw2774/.cache/torch/hub/pytorch_vision_v0.10.0
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
zoom_blur_loader = corrupted_dataloaders[0]['train']

# %%
corrects = 0
for images, labels in zoom_blur_loader:
    outputs = model(images)
    _, preds = torch.max(outputs, 1)
    corrects += torch.sum(preds == labels.data)
total_accuracy = corrects/corrupted_dataset_sizes[0]['train']

# %%
torch.sum(preds == y.data)
# Out:
# tensor(15)
